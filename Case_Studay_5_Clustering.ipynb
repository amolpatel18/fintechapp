# %% [markdown]
# <a href="https://colab.research.google.com/github/amolpatel18/fintechapp/blob/main/Case_Studay_5_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #How to Interpret this submission?
# 1. All the text boxs starting with text "Conclusion" are the answer to the queries in the business case
# 2. All the Text boxes starting with text "AI Generated" is the AI generated text, it's for the student's later reference.

# %%
# !pip -q install gdown

# %%
# !gdown --folder  "https://drive.google.com/drive/folders/1pDtimhRel-n_k7JqpXMBhMutu3Lyqr1q"
# Out:
# Retrieving folder contents
# Processing file 1DkYJatq6862u96r1u3R-HbUDGIkKRcOt Manual Clustering Example.xlsx
# Processing file 1LkXuYCnFPOEyI4bBk5RRf_f2aHG2I3hk scaler_hashed_for_students.csv
# Processing file 1CMKNSupBcKmmr9qiMsBvf-UjUZaw4SuX scaler_job_positions_mapping VX.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1DkYJatq6862u96r1u3R-HbUDGIkKRcOt
# To: /content/CaseStudy5_Clustering_Scaler/Manual Clustering Example.xlsx
# 100% 10.7k/10.7k [00:00<00:00, 21.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1LkXuYCnFPOEyI4bBk5RRf_f2aHG2I3hk
# To: /content/CaseStudy5_Clustering_Scaler/scaler_hashed_for_students.csv
# 100% 24.7M/24.7M [00:00<00:00, 87.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CMKNSupBcKmmr9qiMsBvf-UjUZaw4SuX
# To: /content/CaseStudy5_Clustering_Scaler/scaler_job_positions_mapping VX.csv
# 100% 33.6k/33.6k [00:00<00:00, 19.5MB/s]
# Download completed

# %%
import pandas as pd
df = pd.read_csv("/content/CaseStudy5_Clustering_Scaler/scaler_hashed_for_students.csv")
df
# Out:
#         Unnamed: 0               company_hash  \
# 0                0             czniswwz sucsk
# 1                1  oznskulz subilihh nshswzc
# 2                2              faulwklwsl ks
# 3                3                  wirijzcsk
# 4                4                 osbw toidj
# ...            ...                        ...
# 205838      206918                  kjjnz sul
# 205839      206919                  djtokclih
# 205840      206920                   kllinswz
# 205841      206921             uiw kjjnslkgnz
# 205842      206922             hiotku fwkunza
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 205838  70027b728c8ee901fe979533ed94ffda97be08fc23f33b...   2008.0   220000
# 205839  7f7292ffad724ebbe9ca860f515245368d714c84705b42...   2017.0   500000
# 205840  cb25cc7304e9a24facda7f5567c7922ffc48e3d5d6018c...   2021.0   700000
# 205841  fb46a1a2752f5f652ce634f6178d0578ef6995ee59f6c8...   2019.0  5100000
# 205842  0bcfc1d05f2e8dc4147743a1313aa70a119b41b30d4a1f...   2014.0  1240000
#
#               job_position  ctc_updated_year
# 0                    Other            2020.0
# 1       FullStack Engineer            2019.0
# 2         Backend Engineer            2020.0
# 3         Backend Engineer            2019.0
# 4       FullStack Engineer            2019.0
# ...                    ...               ...
# 205838                 NaN            2019.0
# 205839                 NaN            2020.0
# 205840                 NaN            2021.0
# 205841                 NaN            2019.0
# 205842                 NaN            2016.0
#
# [205843 rows x 7 columns]

# %%
for col in ['company_hash', 'job_position','ctc_updated_year','ctc']:
  print(col,'='*25,'\n' )
  print(df[col].describe())
  print('\n','&'*25,'\n' )
# Out:
# company_hash =========================
#
# count                        205799
# unique                        37299
# top       wkwk liufdnwkula fzovslzf
# freq                           8337
# Name: company_hash, dtype: object
#
#  &&&&&&&&&&&&&&&&&&&&&&&&&
#
# job_position =========================
#
# count               153279
# unique                1016
# top       Backend Engineer
# freq                 43554
# Name: job_position, dtype: object
#
#  &&&&&&&&&&&&&&&&&&&&&&&&&
#
# ctc_updated_year =========================
#
# count    205843.000000
# mean       2019.628231
# std           1.325104
# min        2015.000000
# 25%        2019.000000
# 50%        2020.000000
# 75%        2021.000000
# max        2021.000000
# Name: ctc_updated_year, dtype: float64
#
#  &&&&&&&&&&&&&&&&&&&&&&&&&
#
# ctc =========================
#
# count    2.058430e+05
# mean     2.271685e+06
# std      1.180091e+07
# min      2.000000e+00
# 25%      5.300000e+05
# 50%      9.500000e+05
# 75%      1.700000e+06
# max      1.000150e+09
# Name: ctc, dtype: float64
#
#  &&&&&&&&&&&&&&&&&&&&&&&&&

# %% [markdown]
# # EDA

# %% [markdown]
# What does “good” look like?
#
# Import the dataset and do usual exploratory data analysis steps like checking the structure & characteristics of the dataset
#
# 0.  You may have to remove special characters from the dataset by using Regex
# Don’t worry if you haven’t used that before. The syntax is quite simple and intuitive
# Code:
# mystring='\tAirtel X Labs'
# re.sub('[^A-Za-z0-9 ]+', '', mystring)
# 1.   Checking unique emails and frequency of occurrence of the same email hash in the data. Recording observation and inference, wherever necessary.
# 2.  Checking for duplicates in the dataset and drop them
# 3. Making some new features like adding ‘Years of Experience’ column by subtracting orgyear from current year
# 4. Checking for missing values and Prepare data for KNN/ Mean Imputation.

# %%
# You may have to remove special characters from the dataset by using Regex
#Don’t worry if you haven’t used that before. The syntax is quite simple and intuitive
#Code:
#mystring='\tAirtel X Labs'
#re.sub('[^A-Za-z0-9 ]+', '', mystring)

# %%
df.isna().count()
# Out:
# Unnamed: 0          205843
# company_hash        205843
# email_hash          205843
# orgyear             205843
# ctc                 205843
# job_position        205843
# ctc_updated_year    205843
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.isna().count()
# Out:
# company_hash        205843
# email_hash          205843
# orgyear             205843
# ctc                 205843
# job_position        205843
# ctc_updated_year    205843
# dtype: int64

# %%
df.count()
# Out:
# company_hash        205799
# email_hash          205843
# orgyear             205757
# ctc                 205843
# job_position        153279
# ctc_updated_year    205843
# dtype: int64

# %%
df.dropna(inplace=True)
df.count()
# Out:
# company_hash        153204
# email_hash          153204
# orgyear             153204
# ctc                 153204
# job_position        153204
# ctc_updated_year    153204
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df[df['job_position'].isna()].count()
# Out:
# company_hash        0
# email_hash          0
# orgyear             0
# ctc                 0
# job_position        0
# ctc_updated_year    0
# dtype: int64

# %%
df
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 205324          lft suwzoukwsiukn
# 205326                    subifaf
# 205327          lihjuivk liuwoklw
# 205328                  cduuedhga
# 205329      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 205324  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 205326  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 205327  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 205328  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 205329  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#               job_position  ctc_updated_year
# 0                    Other            2020.0
# 1       FullStack Engineer            2019.0
# 2         Backend Engineer            2020.0
# 3         Backend Engineer            2019.0
# 4       FullStack Engineer            2019.0
# ...                    ...               ...
# 205324  FullStack Engineer            2021.0
# 205326  FullStack Engineer            2021.0
# 205327      Data Scientist            2021.0
# 205328      Data Scientist            2021.0
# 205329   Frontend Engineer            2021.0
#
# [153186 rows x 6 columns]

# %%
job_map_df = pd.read_csv("/content/CaseStudy5_Clustering_Scaler/scaler_job_positions_mapping VX.csv")

# %%
job_map_df.head()
# Out:
#   Original     New
# 0        7  others
# 1       91  others
# 2      737  others
# 3   857628  others
# 4   896651  others

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#          job_position  ctc_updated_year
# 0               Other            2020.0
# 1  FullStack Engineer            2019.0
# 2    Backend Engineer            2020.0
# 3    Backend Engineer            2019.0
# 4  FullStack Engineer            2019.0

# %%
#Convert to string, lower and remove whitespaces
df['job_position'] = df['job_position'].astype(str)
job_map_df['Original'] = job_map_df['Original'].astype(str)
job_map_df['New'] = job_map_df['New'].astype(str)


df['job_position']    = df['job_position'].str.strip().str.lower()
job_map_df['Original'] = job_map_df['Original'].str.strip().str.lower()
job_map_df['New'] = job_map_df['New'].str.strip().str.lower()

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#          job_position  ctc_updated_year
# 0               other            2020.0
# 1  fullstack engineer            2019.0
# 2    backend engineer            2020.0
# 3    backend engineer            2019.0
# 4  fullstack engineer            2019.0

# %%
df
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 205324          lft suwzoukwsiukn
# 205326                    subifaf
# 205327          lihjuivk liuwoklw
# 205328                  cduuedhga
# 205329      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 205324  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 205326  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 205327  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 205328  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 205329  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#               job_position  ctc_updated_year
# 0                    other            2020.0
# 1       fullstack engineer            2019.0
# 2         backend engineer            2020.0
# 3         backend engineer            2019.0
# 4       fullstack engineer            2019.0
# ...                    ...               ...
# 205324  fullstack engineer            2021.0
# 205326  fullstack engineer            2021.0
# 205327      data scientist            2021.0
# 205328      data scientist            2021.0
# 205329   frontend engineer            2021.0
#
# [153186 rows x 6 columns]

# %%
df = df.merge(job_map_df,
              how='left',
              left_on='job_position',
              right_on='Original')

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#          job_position  ctc_updated_year            Original  \
# 0               other            2020.0               other
# 1  fullstack engineer            2019.0  fullstack engineer
# 2    backend engineer            2020.0    backend engineer
# 3    backend engineer            2019.0    backend engineer
# 4  fullstack engineer            2019.0  fullstack engineer
#
#                   New
# 0              others
# 1  fullstack devloper
# 2    backend engineer
# 3    backend engineer
# 4  fullstack devloper

# %%
df.drop(columns=['job_position', 'Original'], inplace=True)

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#    ctc_updated_year                 New
# 0            2020.0              others
# 1            2019.0  fullstack devloper
# 2            2020.0    backend engineer
# 3            2019.0    backend engineer
# 4            2019.0  fullstack devloper

# %%
df = df.rename(columns={'New': 'job_position_clean'})

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#    ctc_updated_year  job_position_clean
# 0            2020.0              others
# 1            2019.0  fullstack devloper
# 2            2020.0    backend engineer
# 3            2019.0    backend engineer
# 4            2019.0  fullstack devloper

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153186 entries, 0 to 153185
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   company_hash        153186 non-null  object
#  1   email_hash          153186 non-null  object
#  2   orgyear             153186 non-null  float64
#  3   ctc                 153186 non-null  int64
#  4   ctc_updated_year    153186 non-null  float64
#  5   job_position_clean  152366 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.0+ MB

# %%
df[df['ctc'] == 0].count()
# Out:
# company_hash          0
# email_hash            0
# orgyear               0
# ctc                   0
# ctc_updated_year      0
# job_position_clean    0
# dtype: int64

# %%
df[df['ctc_updated_year'] == 0].count()
# Out:
# company_hash          0
# email_hash            0
# orgyear               0
# ctc                   0
# ctc_updated_year      0
# job_position_clean    0
# dtype: int64

# %%
#Create New column Experience
df['experience'] = df['ctc_updated_year'] - df['orgyear']

# %%
import matplotlib.pyplot as plt
plt.plot(df.experience)

# %%
df['experience'].value_counts()
# Out:
# experience
#  2.0       20868
#  3.0       20176
#  4.0       17896
#  1.0       16168
#  5.0       14876
#            ...
# -186.0         1
#  119.0         1
#  1981.0        1
#  1816.0        1
#  1819.0        1
# Name: count, Length: 72, dtype: int64

# %%
#Experiece clean-up
df = df[~((df['experience'] > 25) | (df['experience'] < 0))]

# %%
df['experience'].value_counts()
# Out:
# experience
# 2.0     20868
# 3.0     20176
# 4.0     17896
# 1.0     16168
# 5.0     14876
# 6.0     11638
# 7.0      9093
# 0.0      8346
# 8.0      6799
# 9.0      5169
# 10.0     3745
# 11.0     2678
# 12.0     2108
# 13.0     1696
# 14.0     1511
# 15.0     1227
# 16.0      942
# 17.0      696
# 18.0      542
# 19.0      504
# 20.0      442
# 21.0      274
# 22.0      202
# 23.0      139
# 24.0       83
# 25.0       65
# Name: count, dtype: int64

# %%
job_map_df.head()
# Out:
#   Original     New
# 0        7  others
# 1       91  others
# 2      737  others
# 3   857628  others
# 4   896651  others

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#    ctc_updated_year  job_position_clean  experience
# 0            2020.0              others         4.0
# 1            2019.0  fullstack devloper         1.0
# 2            2020.0    backend engineer         5.0
# 3            2019.0    backend engineer         2.0
# 4            2019.0  fullstack devloper         2.0

# %%
df['job_position_clean'].isna().count()
# Out:
# np.int64(147883)

# %%
job_map_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Original  801 non-null    object
#  1   New       801 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB

# %%
df.dropna(inplace=True)
df.count()
# Out:
# company_hash          147100
# email_hash            147100
# orgyear               147100
# ctc                   147100
# ctc_updated_year      147100
# job_position_clean    147100
# experience            147100
# dtype: int64

# %%
df.ctc.min()
# Out:
# 2

# %%
df.ctc.max()
# Out:
# 200000000

# %%
lower = df['ctc'].quantile(0.05)
upper = df['ctc'].quantile(0.99)

df = df[(df['ctc'] >= lower) & (df['ctc'] <= upper)]

# %%
df.ctc.max()
# Out:
# 13000000

# %%
df.ctc.min()
# Out:
# 200000

# %%
df[df['ctc'] == 200000]
# Out:
#                     company_hash  \
# 61                          qini
# 82                      takuceku
# 116            jszwzle findwsiuf
# 176     fsutfaf fibwmkoz jvw nwc
# 193              kgesjok lkjswkn
# ...                          ...
# 152530            nzi wzleuifibw
# 152671                  bozfezof
# 152683            gzkdwi fafwzhf
# 152692        lnslr wezokjzdwslf
# 152948           kdtdfw eihz sul
#
#                                                email_hash  orgyear     ctc  \
# 61      03f3f5604f4fd3abcefc1b07e5525fe0b8513b13652be3...   2016.0  200000
# 82      1f5dc52a9c357d9f314f449b8c195cec80d95205d21c96...   2018.0  200000
# 116     d726e41fff8cf17c98d40bd5445fa20690c4363415a3b7...   2018.0  200000
# 176     9fb5df0df799ecddabdcc4235eab560b09b6d108c492e8...   2019.0  200000
# 193     f1bb8aabadbf145df05bce086f890efa558e5705b4579a...   2019.0  200000
# ...                                                   ...      ...     ...
# 152530  0b728f3b385709dac9ab377d3e0925be2659229f700916...   2017.0  200000
# 152671  b3ea45ae465e5a7aab4c3a411b60be66be6878be5b5dd5...   2018.0  200000
# 152683  cb68a80928d8e50221918d2af2e74470ecbac2696ea582...   2017.0  200000
# 152692  9355efa41fb5740dcb82c90f033d6a56a87811095ef793...   2018.0  200000
# 152948  e4b35a43861f23013ed6354a1b77cafdd4bc789175e68d...   2017.0  200000
#
#         ctc_updated_year  job_position_clean  experience
# 61                2019.0              others         3.0
# 82                2021.0              others         3.0
# 116               2021.0  fullstack devloper         3.0
# 176               2019.0  fullstack devloper         0.0
# 193               2019.0  fullstack devloper         0.0
# ...                  ...                 ...         ...
# 152530            2020.0    backend engineer         3.0
# 152671            2020.0              others         2.0
# 152683            2021.0    backend engineer         4.0
# 152692            2021.0    backend engineer         3.0
# 152948            2020.0    backend engineer         3.0
#
# [1451 rows x 7 columns]

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#    ctc_updated_year  job_position_clean  experience
# 0            2020.0              others         4.0
# 1            2019.0  fullstack devloper         1.0
# 2            2020.0    backend engineer         5.0
# 3            2019.0    backend engineer         2.0
# 4            2019.0  fullstack devloper         2.0

# %%
#Checking unique emails and frequency of occurrence of the same email hash in the data. Recording observation and inference, wherever necessary.
tmp = df['email_hash'].value_counts().reset_index()

# %%
tmp
# Out:
#                                                email_hash  count
# 0       6842660273f70e9aa239026ba33bfe82275d6ab0d20124...      9
# 1       3e5e49daa5527a6d5a33599b238bf9bf31e85b9efa9a94...      9
# 2       bbace3cc586400bbc65765bc6a16b77d8913836cfc98b7...      8
# 3       298528ce3160cc761e4dc37a07337ee2e0589df251d736...      8
# 4       c0eb129061675da412b0deb15871dd06ef0d7cd86eb5f7...      8
# ...                                                   ...    ...
# 120583  36cea4f76d85ce12e03d02cb461d7dc4d5c9dd9560990b...      1
# 120584  67f721d083ad4a47137d75173fad0840124f2d17fc6fda...      1
# 120585  fd21ec71881a44fce61c5a25a9d1c6e4713207b843c845...      1
# 120586  9428bdb40ad39856a30ea4451fbf5daf416773df765b28...      1
# 120587  172f39a9242aa1800333221019934b6458bafcecea38c5...      1
#
# [120588 rows x 2 columns]

# %%
tmp = tmp[tmp['count'] > 1]

# %%
tmp
# Out:
#                                               email_hash  count
# 0      6842660273f70e9aa239026ba33bfe82275d6ab0d20124...      9
# 1      3e5e49daa5527a6d5a33599b238bf9bf31e85b9efa9a94...      9
# 2      bbace3cc586400bbc65765bc6a16b77d8913836cfc98b7...      8
# 3      298528ce3160cc761e4dc37a07337ee2e0589df251d736...      8
# 4      c0eb129061675da412b0deb15871dd06ef0d7cd86eb5f7...      8
# ...                                                  ...    ...
# 15228  2997066f4abb5c04679e91e2efc88a329e8efd0f4dc060...      2
# 15229  61a0372b4f6eb184baf97387c7efce6f2d2dd72b779862...      2
# 15230  822e0ec77d3992dde6ae9c540cab3884366811331ba6b7...      2
# 15231  3ef5d23c4b2fb264268fe1497188a87b97d6287a2a5259...      2
# 15232  604fc72870b85d0d8cb6352db478c74079255b7026803d...      2
#
# [15233 rows x 2 columns]

# %%
tmp['count'].value_counts()
# Out:
# count
# 2    12663
# 3     2015
# 4      455
# 5       69
# 6       20
# 7        6
# 8        3
# 9        2
# Name: count, dtype: int64

# %%
tmp = tmp.rename(columns={'count' : 'offer_count'})

# %%
tmp
# Out:
#                                               email_hash  offer_count
# 0      6842660273f70e9aa239026ba33bfe82275d6ab0d20124...            9
# 1      3e5e49daa5527a6d5a33599b238bf9bf31e85b9efa9a94...            9
# 2      bbace3cc586400bbc65765bc6a16b77d8913836cfc98b7...            8
# 3      298528ce3160cc761e4dc37a07337ee2e0589df251d736...            8
# 4      c0eb129061675da412b0deb15871dd06ef0d7cd86eb5f7...            8
# ...                                                  ...          ...
# 15228  2997066f4abb5c04679e91e2efc88a329e8efd0f4dc060...            2
# 15229  61a0372b4f6eb184baf97387c7efce6f2d2dd72b779862...            2
# 15230  822e0ec77d3992dde6ae9c540cab3884366811331ba6b7...            2
# 15231  3ef5d23c4b2fb264268fe1497188a87b97d6287a2a5259...            2
# 15232  604fc72870b85d0d8cb6352db478c74079255b7026803d...            2
#
# [15233 rows x 2 columns]

# %%
df['ctc_updated_year'].describe()
# Out:
# count    139095.000000
# mean       2019.587095
# std           1.230781
# min        2015.000000
# 25%        2019.000000
# 50%        2020.000000
# 75%        2021.000000
# max        2021.000000
# Name: ctc_updated_year, dtype: float64

# %%
df['orgyear'].describe()
# Out:
# count    139095.000000
# mean       2014.702556
# std           4.080635
# min        1992.000000
# 25%        2013.000000
# 50%        2016.000000
# 75%        2018.000000
# max        2021.000000
# Name: orgyear, dtype: float64

# %%
df['ctc_updated_year'].isna().count()
# Out:
# np.int64(139095)

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139095 entries, 0 to 139094
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   company_hash        139095 non-null  object
#  1   email_hash          139095 non-null  object
#  2   orgyear             139095 non-null  float64
#  3   ctc                 139095 non-null  int64
#  4   ctc_updated_year    139095 non-null  float64
#  5   job_position_clean  139095 non-null  object
#  6   experience          139095 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 7.4+ MB

# %%
df = df.merge(tmp,
              how = 'left',
              left_on='email_hash',
              right_on='email_hash')

# %%
df
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count
# 0                 2020.0              others         4.0          2.0
# 1                 2019.0  fullstack devloper         1.0          2.0
# 2                 2020.0    backend engineer         5.0          2.0
# 3                 2019.0    backend engineer         2.0          NaN
# 4                 2019.0  fullstack devloper         2.0          2.0
# ...                  ...                 ...         ...          ...
# 139090            2021.0  fullstack devloper         5.0          2.0
# 139091            2021.0  fullstack devloper         2.0          NaN
# 139092            2021.0      data scientist         6.0          2.0
# 139093            2021.0      data scientist         2.0          NaN
# 139094            2021.0  frontend developer         4.0          NaN
#
# [139095 rows x 8 columns]

# %%
df['offer_count'] = df.offer_count.fillna(1)

# %%
df
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count
# 0                 2020.0              others         4.0          2.0
# 1                 2019.0  fullstack devloper         1.0          2.0
# 2                 2020.0    backend engineer         5.0          2.0
# 3                 2019.0    backend engineer         2.0          1.0
# 4                 2019.0  fullstack devloper         2.0          2.0
# ...                  ...                 ...         ...          ...
# 139090            2021.0  fullstack devloper         5.0          2.0
# 139091            2021.0  fullstack devloper         2.0          1.0
# 139092            2021.0      data scientist         6.0          2.0
# 139093            2021.0      data scientist         2.0          1.0
# 139094            2021.0  frontend developer         4.0          1.0
#
# [139095 rows x 8 columns]

# %% [markdown]
# how many folks got multiple offers offer_count > 1 in same year and diff_year

# %%
df_gr_email_ctcupyear = df.groupby(['email_hash','ctc_updated_year']).size().reset_index(name='offer_count')

# %%
df_gr_email_ctcupyear.head()
# Out:
#                                           email_hash  ctc_updated_year  \
# 0  00003288036a44374976948c327f246fdbdf0778546904...            2019.0
# 1  0000aaa0e6b61f7636af1954b43d294484cd151c9b3cf6...            2020.0
# 2  000120d0c8aa304fcf12ab4b85e21feb80a342cfea03d4...            2021.0
# 3  0001b94dbb1e85477b07fb6558ead3456c3735893c81f4...            2020.0
# 4  0001b94dbb1e85477b07fb6558ead3456c3735893c81f4...            2021.0
#
#    offer_count
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df_multi_offer_same_year = df_gr_email_ctcupyear[ df_gr_email_ctcupyear['offer_count'] > 1]

# %%
df_multi_offer_same_year
# Out:
#                                                email_hash  ctc_updated_year  \
# 14      00083d053a4ebf8e8eb99c08c63e0183a70caa0ce348a5...            2020.0
# 36      001059a637996b0b09d5fcbcd8b40d8e1f6cfa62b18b10...            2021.0
# 45      00154fd1e62658a3caa5f7e3260b6338293ee614235bcb...            2020.0
# 51      0018d91337b46826a70a961962abbd7a8a8e8036e678bc...            2020.0
# 56      001b3125da5372767bc5c560066e7e53525f2aece726e6...            2019.0
# ...                                                   ...               ...
# 125648  ffe288a7eb673fcd177e4a933e3c090f15e95b938a8c0e...            2020.0
# 125650  ffe407064ff7580666a650bb87a212a99435775b42e5aa...            2021.0
# 125656  ffe8b4edc31c9e237a8068b3a94224628f05dac96041fb...            2021.0
# 125657  ffe96dccfd7cb9e6048a382bbdc511be147ceaa7de3ada...            2019.0
# 125668  ffef2cf7fc8f3b5fafb8563cdfb29f1fa892d05239b2f4...            2019.0
#
#         offer_count
# 14                2
# 36                2
# 45                2
# 51                3
# 56                3
# ...             ...
# 125648            2
# 125650            2
# 125656            2
# 125657            2
# 125668            2
#
# [11672 rows x 3 columns]

# %%
len(df_multi_offer_same_year) / len(df) * 100
# Out:
# 8.391387181422768

# %% [markdown]
# #Conclusion 1 : 8.21% of the folks got multiple offers in the same Year

# %% [markdown]
# ** Manual Clustering ** on the basis of learner’s company, job position and years of experience
#
# Getting the 5 point summary of CTC (mean, median, max, min, count etc) on the basis of Company, Job Position, Years of Experience
#
# Merging the same with original dataset carefully and creating some flags showing learners with CTC greater than the Average of their Company’s department having same Years of Experience - Call that flag designation with values [1,2,3]
# Doing above analysis at Company & Job Position level. Name that flag Class with values [1,2,3]
# Repeating the same analysis at the Company level. Name that flag Tier with values [1,2,3]
# Based on the manual clustering done so far, answering few questions like:
# Top 10 employees (earning more than most of the employees in the company) - Tier 1
# Top 10 employees of data science in each company earning more than their peers - Class 1
# Bottom 10 employees of data science in each company earning less than their peers - Class 3
# Bottom 10 employees (earning less than most of the employees in the company)- Tier 3
# Top 10 employees in each company - X department - having 5/6/7 years of experience earning more than their peers - Tier X
# Top 10 companies (based on their CTC)
# Top 2 positions in every company (based on their CTC)
# Data processing for Unsupervised clustering - Label encoding/ One- hot encoding, Standardization of data

# %%
df.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#    ctc_updated_year  job_position_clean  experience  offer_count
# 0            2020.0              others         4.0          2.0
# 1            2019.0  fullstack devloper         1.0          2.0
# 2            2020.0    backend engineer         5.0          2.0
# 3            2019.0    backend engineer         2.0          1.0
# 4            2019.0  fullstack devloper         2.0          2.0

# %%
#Getting the 5 point summary of CTC (mean, median, max, min, count etc) on the basis of Company, Job Position, Years of Experience
gr_ctc = df.groupby(['company_hash','job_position_clean','experience'])['ctc'].agg(
        count='count',
        mean='mean',
        median='median',
        min='min',
        max='max'
    ).reset_index()

# %%
gr_ctc
# Out:
#                          company_hash  job_position_clean  experience  count  \
# 0                                0000              others         3.0      1
# 1                          01 fauzota    android engineer         3.0      1
# 2                          01 fauzota  frontend developer         8.0      1
# 3      05gu bsuezknwe josvkwz nshswzc    backend engineer         2.0      1
# 4                              1 azko    backend engineer         1.0      2
# ...                               ...                 ...         ...    ...
# 83140                zzhzqz fibw wzle  frontend developer         8.0      1
# 83141                zzm wzleuinitszf     devops engineer         5.0      1
# 83142                zzm wzleuinitszf              others         5.0      1
# 83143                    zzqansbz sul  fullstack devloper         2.0      1
# 83144                     zzqaukdrkos    android engineer         5.0      1
#
#             mean     median      min      max
# 0       300000.0   300000.0   300000   300000
# 1       270000.0   270000.0   270000   270000
# 2       830000.0   830000.0   830000   830000
# 3      1100000.0  1100000.0  1100000  1100000
# 4      1180000.0  1180000.0   660000  1700000
# ...          ...        ...      ...      ...
# 83140  1000000.0  1000000.0  1000000  1000000
# 83141   800000.0   800000.0   800000   800000
# 83142   800000.0   800000.0   800000   800000
# 83143   710000.0   710000.0   710000   710000
# 83144  2400000.0  2400000.0  2400000  2400000
#
# [83145 rows x 8 columns]

# %%
gr_ctc[gr_ctc['count']>1]
# Out:
#            company_hash  job_position_clean  experience  count          mean  \
# 4                1 azko    backend engineer         1.0      2  1.180000e+06
# 15              10wshzf  fullstack devloper         1.0      2  4.050000e+05
# 35        1fsnvzogdnnzw  fullstack devloper         1.0      2  1.100000e+06
# 41                  1ht    android engineer         1.0      2  7.500000e+05
# 44                  1ht    backend engineer         1.0      2  1.100000e+06
# ...                 ...                 ...         ...    ...           ...
# 83055        zywokhkorf              others         1.0      3  6.500000e+05
# 83074  zywozhz uzwmiorf    backend engineer         2.0      3  1.116667e+06
# 83075  zywozhz uzwmiorf    backend engineer         3.0      4  1.175000e+06
# 83076  zywozhz uzwmiorf    backend engineer         6.0      2  1.750000e+06
# 83085  zywozhz uzwmiorf              others         3.0      2  1.180000e+06
#
#           median      min      max
# 4      1180000.0   660000  1700000
# 15      405000.0   400000   410000
# 35     1100000.0  1100000  1100000
# 41      750000.0   600000   900000
# 44     1100000.0  1000000  1200000
# ...          ...      ...      ...
# 83055   600000.0   550000   800000
# 83074  1050000.0  1050000  1250000
# 83075  1300000.0   800000  1300000
# 83076  1750000.0  1500000  2000000
# 83085  1180000.0  1060000  1300000
#
# [14366 rows x 8 columns]

# %%
mrg_col = ['company_hash','job_position_clean','experience']
df_mrg_ctc = df.merge(gr_ctc,'left',left_on=mrg_col, right_on=mrg_col)

# %%
df_mrg_ctc
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 1                 2019.0  fullstack devloper         1.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 3                 2019.0    backend engineer         2.0          1.0     10
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# ...                  ...                 ...         ...          ...    ...
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139091            2021.0  fullstack devloper         2.0          1.0    172
# 139092            2021.0      data scientist         6.0          2.0      1
# 139093            2021.0      data scientist         2.0          1.0      2
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#                 mean     median      min      max
# 0       1.085000e+06  1085000.0  1070000  1100000
# 1       4.599995e+05   459999.5   449999   470000
# 2       2.000000e+06  2000000.0  2000000  2000000
# 3       1.344000e+06  1375000.0   700000  1950000
# 4       1.000000e+06  1000000.0   600000  1400000
# ...              ...        ...      ...      ...
# 139090  1.500000e+06  1500000.0  1500000  1500000
# 139091  5.439243e+05   420000.0   300000  1800000
# 139092  1.000000e+06  1000000.0  1000000  1000000
# 139093  1.150000e+06  1150000.0  1100000  1200000
# 139094  1.100000e+06  1100000.0  1100000  1100000
#
# [139095 rows x 13 columns]

# %%
df_mrg_ctc['ctc_above_avg'] = df_mrg_ctc.apply(lambda row: 1 if row['ctc'] > row['mean'] else 0, axis=1)

# %%
import numpy as np

df_mrg_ctc['ctc_status'] = np.where(
    df_mrg_ctc['ctc'] < df_mrg_ctc['mean'],
    1,                                      # lower than avg
    np.where(
        df_mrg_ctc['ctc'] > df_mrg_ctc['mean'],
        3,                                  # above avg
        2                                   # equal to avg
    )
)

# %%
df_mrg_ctc.head()
# Out:
#                 company_hash  \
# 0             czniswwz sucsk
# 1  oznskulz subilihh nshswzc
# 2              faulwklwsl ks
# 3                  wirijzcsk
# 4                 osbw toidj
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#    ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0            2020.0              others         4.0          2.0      2
# 1            2019.0  fullstack devloper         1.0          2.0      2
# 2            2020.0    backend engineer         5.0          2.0      1
# 3            2019.0    backend engineer         2.0          1.0     10
# 4            2019.0  fullstack devloper         2.0          2.0      2
#
#         mean     median      min      max  ctc_above_avg  ctc_status
# 0  1085000.0  1085000.0  1070000  1100000              1           3
# 1   459999.5   459999.5   449999   470000              0           1
# 2  2000000.0  2000000.0  2000000  2000000              0           2
# 3  1344000.0  1375000.0   700000  1950000              0           1
# 4  1000000.0  1000000.0   600000  1400000              1           3

# %%
df_mrg_ctc
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 1                 2019.0  fullstack devloper         1.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 3                 2019.0    backend engineer         2.0          1.0     10
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# ...                  ...                 ...         ...          ...    ...
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139091            2021.0  fullstack devloper         2.0          1.0    172
# 139092            2021.0      data scientist         6.0          2.0      1
# 139093            2021.0      data scientist         2.0          1.0      2
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#                 mean     median      min      max  ctc_above_avg  ctc_status
# 0       1.085000e+06  1085000.0  1070000  1100000              1           3
# 1       4.599995e+05   459999.5   449999   470000              0           1
# 2       2.000000e+06  2000000.0  2000000  2000000              0           2
# 3       1.344000e+06  1375000.0   700000  1950000              0           1
# 4       1.000000e+06  1000000.0   600000  1400000              1           3
# ...              ...        ...      ...      ...            ...         ...
# 139090  1.500000e+06  1500000.0  1500000  1500000              0           2
# 139091  5.439243e+05   420000.0   300000  1800000              1           3
# 139092  1.000000e+06  1000000.0  1000000  1000000              0           2
# 139093  1.150000e+06  1150000.0  1100000  1200000              0           1
# 139094  1.100000e+06  1100000.0  1100000  1100000              0           2
#
# [139095 rows x 15 columns]

# %%
gr_ctc_company_job = df.groupby(['company_hash','job_position_clean'])['ctc'].agg(
        mean='mean',
        median='median',
        min='min',
        max='max'
    ).reset_index()

# %%
gr_ctc_company_job.rename(columns={'mean':'cp_jb_mean', 'median':'cp_jb_median', 'min':'cp_jb_min','max' : 'cp_jb_max'},inplace=True)

# %%
gr_ctc_company_job
# Out:
#                          company_hash  job_position_clean  cp_jb_mean  \
# 0                                0000              others    300000.0
# 1                          01 fauzota    android engineer    270000.0
# 2                          01 fauzota  frontend developer    830000.0
# 3      05gu bsuezknwe josvkwz nshswzc    backend engineer   1100000.0
# 4                              1 azko    backend engineer   1180000.0
# ...                               ...                 ...         ...
# 51958                zzhzqz fibw wzle  frontend developer   1000000.0
# 51959                zzm wzleuinitszf     devops engineer    800000.0
# 51960                zzm wzleuinitszf              others    800000.0
# 51961                    zzqansbz sul  fullstack devloper    710000.0
# 51962                     zzqaukdrkos    android engineer   2400000.0
#
#        cp_jb_median  cp_jb_min  cp_jb_max
# 0          300000.0     300000     300000
# 1          270000.0     270000     270000
# 2          830000.0     830000     830000
# 3         1100000.0    1100000    1100000
# 4         1180000.0     660000    1700000
# ...             ...        ...        ...
# 51958     1000000.0    1000000    1000000
# 51959      800000.0     800000     800000
# 51960      800000.0     800000     800000
# 51961      710000.0     710000     710000
# 51962     2400000.0    2400000    2400000
#
# [51963 rows x 6 columns]

# %%
mrg_col = ['company_hash','job_position_clean']
df_mrg_ctc = df_mrg_ctc.merge(gr_ctc_company_job,'left',left_on=mrg_col, right_on=mrg_col)

# %%
df_mrg_ctc
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 1                 2019.0  fullstack devloper         1.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 3                 2019.0    backend engineer         2.0          1.0     10
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# ...                  ...                 ...         ...          ...    ...
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139091            2021.0  fullstack devloper         2.0          1.0    172
# 139092            2021.0      data scientist         6.0          2.0      1
# 139093            2021.0      data scientist         2.0          1.0      2
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#                 mean     median      min      max  ctc_above_avg  ctc_status  \
# 0       1.085000e+06  1085000.0  1070000  1100000              1           3
# 1       4.599995e+05   459999.5   449999   470000              0           1
# 2       2.000000e+06  2000000.0  2000000  2000000              0           2
# 3       1.344000e+06  1375000.0   700000  1950000              0           1
# 4       1.000000e+06  1000000.0   600000  1400000              1           3
# ...              ...        ...      ...      ...            ...         ...
# 139090  1.500000e+06  1500000.0  1500000  1500000              0           2
# 139091  5.439243e+05   420000.0   300000  1800000              1           3
# 139092  1.000000e+06  1000000.0  1000000  1000000              0           2
# 139093  1.150000e+06  1150000.0  1100000  1200000              0           1
# 139094  1.100000e+06  1100000.0  1100000  1100000              0           2
#
#           cp_jb_mean  cp_jb_median  cp_jb_min  cp_jb_max
# 0       1.085000e+06     1085000.0    1070000    1100000
# 1       9.882000e+05      850000.0     300000    2000000
# 2       2.000000e+06     2000000.0    2000000    2000000
# 3       1.563043e+06     1600000.0     520000    3500000
# 4       8.466667e+05      600000.0     540000    1400000
# ...              ...           ...        ...        ...
# 139090  1.546250e+06     1610000.0     550000    2500000
# 139091  6.515222e+05      500000.0     200000    6500000
# 139092  1.000000e+06     1000000.0    1000000    1000000
# 139093  1.301621e+06     1200000.0     467000    2510000
# 139094  1.100000e+06     1100000.0    1100000    1100000
#
# [139095 rows x 19 columns]

# %%
df_mrg_ctc['ctc_cp_jb_status'] = np.where(
    df_mrg_ctc['ctc'] < df_mrg_ctc['cp_jb_mean'],
    1,                                      # lower than avg
    np.where(
        df_mrg_ctc['ctc'] > df_mrg_ctc['cp_jb_mean'],
        3,                                  # above avg
        2                                   # equal to avg
    )
)

# %%
df_mrg_ctc
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 1                 2019.0  fullstack devloper         1.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 3                 2019.0    backend engineer         2.0          1.0     10
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# ...                  ...                 ...         ...          ...    ...
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139091            2021.0  fullstack devloper         2.0          1.0    172
# 139092            2021.0      data scientist         6.0          2.0      1
# 139093            2021.0      data scientist         2.0          1.0      2
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#                 mean     median      min      max  ctc_above_avg  ctc_status  \
# 0       1.085000e+06  1085000.0  1070000  1100000              1           3
# 1       4.599995e+05   459999.5   449999   470000              0           1
# 2       2.000000e+06  2000000.0  2000000  2000000              0           2
# 3       1.344000e+06  1375000.0   700000  1950000              0           1
# 4       1.000000e+06  1000000.0   600000  1400000              1           3
# ...              ...        ...      ...      ...            ...         ...
# 139090  1.500000e+06  1500000.0  1500000  1500000              0           2
# 139091  5.439243e+05   420000.0   300000  1800000              1           3
# 139092  1.000000e+06  1000000.0  1000000  1000000              0           2
# 139093  1.150000e+06  1150000.0  1100000  1200000              0           1
# 139094  1.100000e+06  1100000.0  1100000  1100000              0           2
#
#           cp_jb_mean  cp_jb_median  cp_jb_min  cp_jb_max  ctc_cp_jb_status
# 0       1.085000e+06     1085000.0    1070000    1100000                 3
# 1       9.882000e+05      850000.0     300000    2000000                 1
# 2       2.000000e+06     2000000.0    2000000    2000000                 2
# 3       1.563043e+06     1600000.0     520000    3500000                 1
# 4       8.466667e+05      600000.0     540000    1400000                 3
# ...              ...           ...        ...        ...               ...
# 139090  1.546250e+06     1610000.0     550000    2500000                 1
# 139091  6.515222e+05      500000.0     200000    6500000                 3
# 139092  1.000000e+06     1000000.0    1000000    1000000                 2
# 139093  1.301621e+06     1200000.0     467000    2510000                 1
# 139094  1.100000e+06     1100000.0    1100000    1100000                 2
#
# [139095 rows x 20 columns]

# %%
gr_ctc_company = df.groupby(['company_hash'])['ctc'].agg(mean='mean',
        median='median',
        min='min',
        max='max'
    ).reset_index()

# %%
gr_ctc_company.rename(columns={'mean':'cp_mean', 'median':'cp_median', 'min':'cp_min','max' : 'cp_max'},inplace=True)

# %%
gr_ctc_company
# Out:
#                          company_hash    cp_mean  cp_median   cp_min   cp_max
# 0                                0000   300000.0   300000.0   300000   300000
# 1                          01 fauzota   550000.0   550000.0   270000   830000
# 2      05gu bsuezknwe josvkwz nshswzc  1100000.0  1100000.0  1100000  1100000
# 3                              1 azko  1180000.0  1180000.0   660000  1700000
# 4                          1 cstswknf   350000.0   350000.0   350000   350000
# ...                               ...        ...        ...      ...      ...
# 29984                   zzhjekfaf nwc  1526000.0  1526000.0  1526000  1526000
# 29985                zzhzqz fibw wzle  1000000.0  1000000.0  1000000  1000000
# 29986                zzm wzleuinitszf   800000.0   800000.0   800000   800000
# 29987                    zzqansbz sul   710000.0   710000.0   710000   710000
# 29988                     zzqaukdrkos  2400000.0  2400000.0  2400000  2400000
#
# [29989 rows x 5 columns]

# %%
mrg_col = ['company_hash']
df_mrg_ctc = df_mrg_ctc.merge(gr_ctc_company,'left',left_on=mrg_col, right_on=mrg_col)

# %%
df_mrg_ctc
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 1                 2019.0  fullstack devloper         1.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 3                 2019.0    backend engineer         2.0          1.0     10
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# ...                  ...                 ...         ...          ...    ...
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139091            2021.0  fullstack devloper         2.0          1.0    172
# 139092            2021.0      data scientist         6.0          2.0      1
# 139093            2021.0      data scientist         2.0          1.0      2
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#                 mean  ...  ctc_status    cp_jb_mean  cp_jb_median  cp_jb_min  \
# 0       1.085000e+06  ...           3  1.085000e+06     1085000.0    1070000
# 1       4.599995e+05  ...           1  9.882000e+05      850000.0     300000
# 2       2.000000e+06  ...           2  2.000000e+06     2000000.0    2000000
# 3       1.344000e+06  ...           1  1.563043e+06     1600000.0     520000
# 4       1.000000e+06  ...           3  8.466667e+05      600000.0     540000
# ...              ...  ...         ...           ...           ...        ...
# 139090  1.500000e+06  ...           2  1.546250e+06     1610000.0     550000
# 139091  5.439243e+05  ...           3  6.515222e+05      500000.0     200000
# 139092  1.000000e+06  ...           2  1.000000e+06     1000000.0    1000000
# 139093  1.150000e+06  ...           1  1.301621e+06     1200000.0     467000
# 139094  1.100000e+06  ...           2  1.100000e+06     1100000.0    1100000
#
#         cp_jb_max  ctc_cp_jb_status       cp_mean  cp_median   cp_min  \
# 0         1100000                 3  1.115667e+06  1070000.0   500000
# 1         2000000                 1  1.196112e+06   900000.0   200000
# 2         2000000                 2  2.000000e+06  2000000.0  2000000
# 3         3500000                 1  1.673367e+06  1450000.0   200000
# 4         1400000                 3  9.880000e+05  1000000.0   540000
# ...           ...               ...           ...        ...      ...
# 139090    2500000                 1  1.380294e+06  1100000.0   550000
# 139091    6500000                 3  6.590659e+05   500000.0   200000
# 139092    1000000                 2  1.000000e+06  1000000.0  1000000
# 139093    2510000                 1  1.328455e+06  1200000.0   467000
# 139094    1100000                 2  1.100000e+06  1100000.0  1100000
#
#           cp_max
# 0        1771000
# 1        6000000
# 2        2000000
# 3        4700000
# 4        1400000
# ...          ...
# 139090   4300000
# 139091  12350000
# 139092   1000000
# 139093   2510000
# 139094   1100000
#
# [139095 rows x 24 columns]

# %%
len(df_mrg_ctc.ctc_updated_year.unique())
# Out:
# 7

# %%
df_mrg_ctc['ctc_cp_status'] = np.where(
    df_mrg_ctc['ctc'] < df_mrg_ctc['cp_mean'],
    1,                                      # lower than avg
    np.where(
        df_mrg_ctc['ctc'] > df_mrg_ctc['cp_mean'],
        3,                                  # above avg
        2                                   # equal to avg
    )
)

# %%
df_mrg_ctc
# Out:
#                      company_hash  \
# 0                  czniswwz sucsk
# 1       oznskulz subilihh nshswzc
# 2                   faulwklwsl ks
# 3                       wirijzcsk
# 4                      osbw toidj
# ...                           ...
# 139090          lft suwzoukwsiukn
# 139091                    subifaf
# 139092          lihjuivk liuwoklw
# 139093                  cduuedhga
# 139094      bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1       b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3       effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# ...                                                   ...      ...      ...
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139091  aec7061c552cfd56fe635ca0e9d347d2e63a95dbcd2ef8...   2019.0  1200000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139093  617a49afbc5efc0f1692780d20fc566ba4ed4f1125491c...   2019.0  1100000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 1                 2019.0  fullstack devloper         1.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 3                 2019.0    backend engineer         2.0          1.0     10
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# ...                  ...                 ...         ...          ...    ...
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139091            2021.0  fullstack devloper         2.0          1.0    172
# 139092            2021.0      data scientist         6.0          2.0      1
# 139093            2021.0      data scientist         2.0          1.0      2
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#                 mean  ...    cp_jb_mean  cp_jb_median  cp_jb_min  cp_jb_max  \
# 0       1.085000e+06  ...  1.085000e+06     1085000.0    1070000    1100000
# 1       4.599995e+05  ...  9.882000e+05      850000.0     300000    2000000
# 2       2.000000e+06  ...  2.000000e+06     2000000.0    2000000    2000000
# 3       1.344000e+06  ...  1.563043e+06     1600000.0     520000    3500000
# 4       1.000000e+06  ...  8.466667e+05      600000.0     540000    1400000
# ...              ...  ...           ...           ...        ...        ...
# 139090  1.500000e+06  ...  1.546250e+06     1610000.0     550000    2500000
# 139091  5.439243e+05  ...  6.515222e+05      500000.0     200000    6500000
# 139092  1.000000e+06  ...  1.000000e+06     1000000.0    1000000    1000000
# 139093  1.150000e+06  ...  1.301621e+06     1200000.0     467000    2510000
# 139094  1.100000e+06  ...  1.100000e+06     1100000.0    1100000    1100000
#
#         ctc_cp_jb_status       cp_mean  cp_median   cp_min    cp_max  \
# 0                      3  1.115667e+06  1070000.0   500000   1771000
# 1                      1  1.196112e+06   900000.0   200000   6000000
# 2                      2  2.000000e+06  2000000.0  2000000   2000000
# 3                      1  1.673367e+06  1450000.0   200000   4700000
# 4                      3  9.880000e+05  1000000.0   540000   1400000
# ...                  ...           ...        ...      ...       ...
# 139090                 1  1.380294e+06  1100000.0   550000   4300000
# 139091                 3  6.590659e+05   500000.0   200000  12350000
# 139092                 2  1.000000e+06  1000000.0  1000000   1000000
# 139093                 1  1.328455e+06  1200000.0   467000   2510000
# 139094                 2  1.100000e+06  1100000.0  1100000   1100000
#
#         ctc_cp_status
# 0                   1
# 1                   1
# 2                   2
# 3                   1
# 4                   3
# ...               ...
# 139090              3
# 139091              3
# 139092              2
# 139093              1
# 139094              2
#
# [139095 rows x 25 columns]

# %% [markdown]
# ##Top 10 employees (earning more than most of the employees in the company) - Tier 1

# %%
df_mrg_ctc['ctc_rank_cp'] = df_mrg_ctc.groupby('company_hash')['ctc'].rank(method='dense',ascending=False)

top10_emp_per_cp = df_mrg_ctc[df_mrg_ctc['ctc_rank_cp'] < 11]
print(top10_emp_per_cp[ ['email_hash','company_hash', 'job_position_clean','experience','ctc']].head(30).to_string(index=False))
# Out:
#                                                       email_hash                                  company_hash     job_position_clean  experience      ctc
# 6de0a4417d18ab14334c3f43397fc13b30c35149d70c050c0618caea697c87af                                czniswwz sucsk                 others         4.0  1100000
# 4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e90fd66c9df6b37b9059                                 faulwklwsl ks       backend engineer         5.0  2000000
# 6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520214b31b95211adb095                                    osbw toidj     fullstack devloper         2.0  1400000
# 18f2c4aa2ac9dd3ae8ff74f32d30413f5165565b90d8f21a44173a1f73fbb0f2           ekjjsna duhkooszc hkorzwsut jvw nwc     fullstack devloper         2.0   700000
# 756d35a7f6bb8ffeaffc8fcca9ddbb78e7450fa0de2be0a5e9c8d98eb87f97f9                          kllzuwdoz wzleuinita       backend engineer         0.0   400000
# 72c2171a022115d475c8faac306912a4c95f6dd7fdd320df09a5e9160d2a8385                                    wiyfn wzle           ios engineer         5.0   600000
# 3b99c28818530737364245236fba9a821187fc38cd64455bbd569415b3cd0e59                                        hitnsy       backend engineer         7.0  2030000
# 26ec792de0792706df9beb9a8d37f45d732982e7ea21e2dcf2a6c2167785ac08                             rwl sucsk jvw nwc                 others         7.0   800000
# ae2d82bbcafa60534965f8ac93c9d093fd0712f91ebcec74b95cb4ae593c9683                       sucskhkow suwzohzfe nwc     frontend developer         9.0   800000
# be9363f1468f242f655953b2f088922cb6cad80e62c493335d2e28dcb22fd47e                                   csiu tnigkn engineering leadership        13.0  1550000
# 62cc9b3bfd5113bbe365ab1df817e8739fff379e439f84452f959556543ed086                                      xdkuwjes         data scientist         1.0  1350000
# d2668cb959e5657c3881413257b9850caa1359c7ce959ae88cfca4486329e234                                wshzf suwzouzw       backend engineer         4.0  9500000
# f83757429132b93fd3bdceeadc0e52b52de6a78e414f5f5336d1db9a80928dac                              kqlih wzleuinita       backend engineer         0.0   650000
# 65801e6e2e0d70deafcd5fcd0b476af33759c79906f692641ab0f89847e0cd2c                                        osbwsi       backend engineer         5.0  2600000
# 430fb1ff7ee821288dd9cb51fa973bcc170b1b0c63ae6d521e09b6a40a47bb0c                     csiu tnigkn findwsiuf nwc       backend engineer         1.0   500000
# 7ed9dad40408750d848b8c1e568746be7ac2947ec098e68d6a9f2f5324c73679                                          ikws     frontend developer         8.0   780000
# d62c27ef153866e66c72544f81fc3186953a51d66828481836fe3de6ef07937e                              uyt nkgf jvw nwc                 others         4.0   280000
# ba5454243306a2afe8da0731ac189480d2c70fcf694417c406967fce97b63471                   ozlriufaf wzle nkgf jvw nwc     fullstack devloper         4.0  1500000
# 2b3c8ccf6d8de170147719d703ea1cefd2a6241e224afe6940f903f676f4ee89                    kfjsoz vsfsiu wzle nshswzc     engineering intern         0.0   700000
# 69ef6838be8ee5b628375b4cc160ba54c1f7cab8c3b130b13e8bfccca83097de                                    bkuusz hkz            qa engineer        13.0 11800000
# 539a514de313a1bb09b0de185a8281ab6ec6b6259b0096cbcf48243e06d6c6ba                                    swjoibiduc      research engineer         3.0   600000
# 096428e1fb11b50c8112b207e852ee481104cc57d101064d3f3fa3d8666340be    nswhdfmionc hkorzwsut wzleuinitszf jvw nwc     fullstack devloper         5.0  1500000
# 738318c479954b0dc59d17cf391a9fc9a4b0a5ab42aaf4f7b8389691959c5b5a                                        fioili     frontend developer         8.0  2500000
# 43995a553dac3dc4759b6c75eb45c86ffd0beb5fc5c1a85e1d6db2a17163cb4e                 gosctzs2s kuknawslf findwsiuf       backend engineer         3.0   550000
# 1fce874cfd71cbceffe913f3ec47c7d7214d122b30a1cb0ba9900878d6abd724                        kntiflknz wzleuinitszf     fullstack devloper         4.0   300000
# e802e08972e7331357d46d0ce252192cc1dbad79fae7859dd132b2323a149c8d                                          dtkh     fullstack devloper         6.0  1250000
# 3e0f073e09d14faecf2e754fe588e2b056cac1b9bc1efe59375231d182b5707e                              kjjvszmy jvw nwc       backend engineer         8.0  2700000
# e52b00ac9a839a932a5ff6583572f2192913abf67b21f5e098ae8c457e5eae7f jokwsfeweku fibwmkoz vzuwdozf josvkwz nshswzc       backend engineer         2.0   600000
# cf01b5e9c5a3eaa8dee352a8d427827c6e77ce46e143a480f0e704c48be6a2d1                                   bnzywoiuslf     fullstack devloper         1.0  1100000
# e6e48ebccf5643cc3fa9a4c552e1351240d96e9b92831437722c43172c5a8012                                   kgj eincsut       backend engineer         3.0   660000

# %%
top10_emp_per_cp
# Out:
#                                   company_hash  \
# 0                               czniswwz sucsk
# 2                                faulwklwsl ks
# 4                                   osbw toidj
# 5          ekjjsna duhkooszc hkorzwsut jvw nwc
# 7                         kllzuwdoz wzleuinita
# ...                                        ...
# 139081  fkhfdut oc sufwswdwz sucsk   gkutknioz
# 139083                                 lkotsnn
# 139090                       lft suwzoukwsiukn
# 139092                       lihjuivk liuwoklw
# 139094                   bnzywokcz fafwzhf nhw
#
#                                                email_hash  orgyear      ctc  \
# 0       6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 2       4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 4       6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
# 5       18f2c4aa2ac9dd3ae8ff74f32d30413f5165565b90d8f2...   2018.0   700000
# 7       756d35a7f6bb8ffeaffc8fcca9ddbb78e7450fa0de2be0...   2019.0   400000
# ...                                                   ...      ...      ...
# 139081  9428bdb40ad39856a30ea4451fbf5daf416773df765b28...   2018.0  2400000
# 139083  2e23f5a7124dfb3b8179c49aa09e3f623af67b946413d8...   2020.0  1600000
# 139090  ee1e251ebb54cffeddc09244bbc0ed122a1cf59511bbc1...   2016.0  1500000
# 139092  251f5f33672f58c65f43e94d0fc0fef69a7f6149b3b4db...   2015.0  1000000
# 139094  8400c092bfe0b5baca38888c8cf2b9fda5e206c9812a22...   2017.0  1100000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 0                 2020.0              others         4.0          2.0      2
# 2                 2020.0    backend engineer         5.0          2.0      1
# 4                 2019.0  fullstack devloper         2.0          2.0      2
# 5                 2020.0  fullstack devloper         2.0          2.0      1
# 7                 2019.0    backend engineer         0.0          1.0      1
# ...                  ...                 ...         ...          ...    ...
# 139081            2021.0    backend engineer         3.0          1.0      1
# 139083            2021.0  fullstack devloper         1.0          1.0      1
# 139090            2021.0  fullstack devloper         5.0          2.0      1
# 139092            2021.0      data scientist         6.0          2.0      1
# 139094            2021.0  frontend developer         4.0          1.0      1
#
#              mean  ...  cp_jb_median  cp_jb_min  cp_jb_max  ctc_cp_jb_status  \
# 0       1085000.0  ...     1085000.0    1070000    1100000                 3
# 2       2000000.0  ...     2000000.0    2000000    2000000                 2
# 4       1000000.0  ...      600000.0     540000    1400000                 3
# 5        700000.0  ...      700000.0     700000     700000                 2
# 7        400000.0  ...     1005000.0     400000    3500000                 1
# ...           ...  ...           ...        ...        ...               ...
# 139081  2400000.0  ...     2400000.0    2400000    2400000                 2
# 139083  1600000.0  ...     1635000.0    1600000    1670000                 1
# 139090  1500000.0  ...     1610000.0     550000    2500000                 1
# 139092  1000000.0  ...     1000000.0    1000000    1000000                 2
# 139094  1100000.0  ...     1100000.0    1100000    1100000                 2
#
#              cp_mean  cp_median   cp_min   cp_max  ctc_cp_status  ctc_rank_cp
# 0       1.115667e+06  1070000.0   500000  1771000              1          4.0
# 2       2.000000e+06  2000000.0  2000000  2000000              2          1.0
# 4       9.880000e+05  1000000.0   540000  1400000              3          1.0
# 5       9.066667e+05   700000.0   620000  2000000              1          3.0
# 7       8.740000e+05   640000.0   300000  3500000              1         10.0
# ...              ...        ...      ...      ...            ...          ...
# 139081  2.000000e+06  2000000.0  1600000  2400000              3          1.0
# 139083  1.161000e+06  1100000.0   500000  2400000              3          3.0
# 139090  1.380294e+06  1100000.0   550000  4300000              3          7.0
# 139092  1.000000e+06  1000000.0  1000000  1000000              2          1.0
# 139094  1.100000e+06  1100000.0  1100000  1100000              2          1.0
#
# [63436 rows x 26 columns]

# %% [markdown]
# ## Conclusion 2 : Top 10 employees (earning more than most of the employees in the company) - Tier 1

# %%
# Sort by company first, then by CTC descending
df_mrg_ctc_sorted = df_mrg_ctc.sort_values(['company_hash', 'ctc'], ascending=[True, False])

# For each company, take the top 10 earners
top10_per_company = df_mrg_ctc_sorted.groupby('company_hash').head(10)

print(top10_per_company[['company_hash','email_hash','ctc']].head(20).to_string(index=False))
# Out:
#                    company_hash                                                       email_hash      ctc
#                            0000 b3f3bb98cbca4b1ce5dfd5abb4e500ce6f6b66288a5202ead573964201d24b24   300000
#                      01 fauzota e1e15fada844f35fcc33927343d0c80f55526b87c40eeed72b25ceafc1186e5e   830000
#                      01 fauzota 819789ff4068fd5c8facf8a5074cdd2e1ff989c95ae02c02b81ac1447cbd6386   270000
#  05gu bsuezknwe josvkwz nshswzc 4702229ffb6968c87b16fc57e730769e554184e322e1118fbd997a1d8e50dec0  1100000
#                          1 azko 034ae72dd3b77497e96173751f8805d5314bc2363e30c213137be4a5065dd1ef  1700000
#                          1 azko 26a4487b5be40da1e942bf3bc1189172727de0e1c74c5eb7cc77b591fa97fff1   660000
#                      1 cstswknf 70459269ec53bd863dc3bad03772c608842ce6182710e1ad40e66b1ebe578baf   350000
#       10 cstswkn  cdgks  niuciu dbe475d9ad7bfb41d4fffe71787b26f8dadf1f12885ed8e7f12642dc9e27dc52  1300000
#                     1000joipzlw 8e617c175a9b2b244381688471c458f909d4726bd52ff062e902c10a583a2c38   600000
#                       1001 kjjf 48a8c5ecfa89c41d497e6717488bc1083ef78b6a3f6f125af3e35113b55bb7bb  1650000
#                         100jsuf 1f4a7da38c42ab12c561db8ac556c66103ca5350f2c229535ac965db3bfcc613   900000
#             103 fwdcsif jvw nwc ca7ab721db6e55be81164f516dc5349269ffa8d1a07377befa77a8490bd82aaf   320000
#              10bk sucsk jvw nwc dcd91bb9e9ed1d5b9dc8a5e0c5b9afdeb5cece13c997711cc44c4b531f138e71   880000
# 10r subi ckwk findwsiuf jvw nwc 1b57816303d9b21c786a15ad4511d21c8868891605a6d169d04f29eeabb44ad4  1100000
#                             10s 86580f6182f78e8bd4467d579f21f0a0f07c7e9383ba70918fbc93fe499e7c88  1500000
#                         10wshzf 2dde60f4a510b412ac4e8011e806282ecb181a51081751987419151232fc773a   410000
#                         10wshzf 951189c83134ac5394c85c66d0e96f2a0a242f3d99b87db57eaae99d56ce4e9a   400000
#                         10wshzf 2dde60f4a510b412ac4e8011e806282ecb181a51081751987419151232fc773a   400000
#                  10yks nzkousut 48be30753b1dbf2c2fccf43b7f45c51d68bb5725f4ae764fe457adb66df350af   400000
#                  11 suwzouzw fz 22e9c0f7dd48ce922fb963a9d64b8f2f69bda72490bff906286f8c5a9a990230 10000000

# %% [markdown]
# ## Conclusion 5 : Top 2 positions in every company (based on their CTC)

# %%
# For each company, take the top 2 earners
top2_per_company = df_mrg_ctc_sorted.groupby('company_hash').head(2)
print(f"Top 2 Positions in every company based on their CTC")
print(top2_per_company[['company_hash','job_position_clean','ctc']].head(20).to_string(index=False))
# Out:
# Top 2 Positions in every company based on their CTC
#                    company_hash job_position_clean      ctc
#                            0000             others   300000
#                      01 fauzota frontend developer   830000
#                      01 fauzota   android engineer   270000
#  05gu bsuezknwe josvkwz nshswzc   backend engineer  1100000
#                          1 azko   backend engineer  1700000
#                          1 azko   backend engineer   660000
#                      1 cstswknf   backend engineer   350000
#       10 cstswkn  cdgks  niuciu   android engineer  1300000
#                     1000joipzlw frontend developer   600000
#                       1001 kjjf frontend developer  1650000
#                         100jsuf engineering intern   900000
#             103 fwdcsif jvw nwc frontend developer   320000
#              10bk sucsk jvw nwc       data analyst   880000
# 10r subi ckwk findwsiuf jvw nwc fullstack devloper  1100000
#                             10s   android engineer  1500000
#                         10wshzf fullstack devloper   410000
#                         10wshzf frontend developer   400000
#                  10yks nzkousut     data scientist   400000
#                  11 suwzouzw fz   backend engineer 10000000
#                    11wzlefxdkoz   backend engineer   360000

# %% [markdown]
# #Conclusion 2 : Bottom 10 employees (earning less than most of the employees in the company)- Tier 3

# %%
# Sort by company first, then by CTC ascending
df_mrg_ctc_sorted_asc = df_mrg_ctc.sort_values(['company_hash', 'ctc'], ascending=[True, True])

# For each company, take the bottom 10 earners
Bottom10_per_company = df_mrg_ctc_sorted_asc.groupby('company_hash').head(10)

print(Bottom10_per_company[['company_hash','email_hash','ctc','ctc_rank_cp']].head(200).to_string(index=False))
# Out:
#                               company_hash                                                       email_hash      ctc  ctc_rank_cp
#                                       0000 b3f3bb98cbca4b1ce5dfd5abb4e500ce6f6b66288a5202ead573964201d24b24   300000          1.0
#                                 01 fauzota 819789ff4068fd5c8facf8a5074cdd2e1ff989c95ae02c02b81ac1447cbd6386   270000          2.0
#                                 01 fauzota e1e15fada844f35fcc33927343d0c80f55526b87c40eeed72b25ceafc1186e5e   830000          1.0
#             05gu bsuezknwe josvkwz nshswzc 4702229ffb6968c87b16fc57e730769e554184e322e1118fbd997a1d8e50dec0  1100000          1.0
#                                     1 azko 26a4487b5be40da1e942bf3bc1189172727de0e1c74c5eb7cc77b591fa97fff1   660000          2.0
#                                     1 azko 034ae72dd3b77497e96173751f8805d5314bc2363e30c213137be4a5065dd1ef  1700000          1.0
#                                 1 cstswknf 70459269ec53bd863dc3bad03772c608842ce6182710e1ad40e66b1ebe578baf   350000          1.0
#                  10 cstswkn  cdgks  niuciu dbe475d9ad7bfb41d4fffe71787b26f8dadf1f12885ed8e7f12642dc9e27dc52  1300000          1.0
#                                1000joipzlw 8e617c175a9b2b244381688471c458f909d4726bd52ff062e902c10a583a2c38   600000          1.0
#                                  1001 kjjf 48a8c5ecfa89c41d497e6717488bc1083ef78b6a3f6f125af3e35113b55bb7bb  1650000          1.0
#                                    100jsuf 1f4a7da38c42ab12c561db8ac556c66103ca5350f2c229535ac965db3bfcc613   900000          1.0
#                        103 fwdcsif jvw nwc ca7ab721db6e55be81164f516dc5349269ffa8d1a07377befa77a8490bd82aaf   320000          1.0
#                         10bk sucsk jvw nwc dcd91bb9e9ed1d5b9dc8a5e0c5b9afdeb5cece13c997711cc44c4b531f138e71   880000          1.0
#            10r subi ckwk findwsiuf jvw nwc 1b57816303d9b21c786a15ad4511d21c8868891605a6d169d04f29eeabb44ad4  1100000          1.0
#                                        10s 86580f6182f78e8bd4467d579f21f0a0f07c7e9383ba70918fbc93fe499e7c88  1500000          1.0
#                                    10wshzf 951189c83134ac5394c85c66d0e96f2a0a242f3d99b87db57eaae99d56ce4e9a   400000          2.0
#                                    10wshzf 2dde60f4a510b412ac4e8011e806282ecb181a51081751987419151232fc773a   400000          2.0
#                                    10wshzf 2dde60f4a510b412ac4e8011e806282ecb181a51081751987419151232fc773a   410000          1.0
#                             10yks nzkousut 48be30753b1dbf2c2fccf43b7f45c51d68bb5725f4ae764fe457adb66df350af   400000          1.0
#                             11 suwzouzw fz 22e9c0f7dd48ce922fb963a9d64b8f2f69bda72490bff906286f8c5a9a990230 10000000          1.0
#                               11wzlefxdkoz 72b92a965f071792a7744a8f18e0118424cef5119e54f32960b6f10ad0468769   360000          1.0
#                121 idwfidolz sucsk jvw nwc 802644427b4013dff716a8afd4184de18595e225862caba76a367fae9a225ade   700000          1.0
#                                  123fwiozf acecb5f871cc747f6111d5b7527a06839178adfe8ec3fe535d621aed0dea6b1b  1030000          2.0
#                                  123fwiozf 160c93562f03a86198438f7b0ba964d1031e7b8c13c9d2daf154b7648907a6df  2560000          1.0
#         12we miuczo ozfzkole sucsk jvw nwc 735aeec9e89759154f3fa4f8f99e3da93b821669684298cd095ab1f3c9513203   650000          1.0
#                                    1337nkg 4b9d46f62ee1534d3bf5337a68a764fd29fc612e9aa87415cd7385f4af3794e1  1650000          1.0
#                                         14 4fa5ac937c7e1ccf1c08380423fb9c92b91071989ea4afc1288533896450fb85   450000          1.0
#                              159 findwsiuf 34899d76060c1f9885967e7b07557104a93d67690d537898b866d1cbb80e7d88   500000          2.0
#                              159 findwsiuf 34899d76060c1f9885967e7b07557104a93d67690d537898b866d1cbb80e7d88   620000          1.0
#                                1820cstswkn 7a64650f7c2c73dfe6b1a4c410eb64641e4dacd371bfda227531bd81c58b70da  1000000          1.0
#                                   18jsyznf 5d10f4f18f723c339ae08817335b05eba9a6c3f139eb5ce6a1c7d628140e1862   720000          1.0
#                            18we wzleuinita 818b746097fd96021ffeec653ceead3dc255518134e45da1b991bc70d3ec169b   850000          1.0
#                                       1985 0e0b52e1fa76e607ca155769bbfb978c4dc91b7482df276817f3f31f0129c9b6  1100000          1.0
#                       1bg fdjjiow fzovslzf e892a6cac1d3858c4ba970468b1760ac6741edbc16a52f5b8663c31e18789ebd  1600000          1.0
#                        1cstswknf findwsiuf cb8268ea29746645dd58e950b08e859ae81a6dcd0daf4cbca42cb08ee7aa9749   650000          1.0
#                              1dj udwoswsiu cbef0c2994978076e076ae2c7fe23e65fae7ba98c0498299dc83675d1fd071b7   840000          1.0
#                              1fsnvzogdnnzw 7d52eee11bcfb389bf315caa398433cc5c785ae28f9a3752cefe16f7524f2b93  1000000          2.0
#                              1fsnvzogdnnzw a0d03ee527c7b65a570818d878ee8222b7c3804302e66fffa4dd8f7791dfa5db  1100000          1.0
#                              1fsnvzogdnnzw 87f6d6ae2aee2286ccee39c6a10cd41346f2efbe5359557207160dd242dd27ba  1100000          1.0
#                             1fw liufdnwkla 0ed9c4584af51265c46f41e5d11af35c3169ef98eb3f70cef75e0feab346c7f4  1100000          1.0
#                                    1fwcsgf 1e59055477fe29d884010f743d2e253968c198a374ccc63e8662e3eec1ffe4bb   700000          2.0
#                                    1fwcsgf 03889a4da71caa7f0083ef4018c2dcca910873b55fce0b9ca0b8c53141f14542  1770000          1.0
#                                 1fwcsgflih a124c79e826df8651feb89bc7f897fb66cf7e0d862677ff1133c9b91105bb73e  2540000          1.0
#          1fwij4ezknwe wzleuinitszf jvw nwc b2133b3ed2cd04d974071a010b7118189c5a6626571ab69b2c53f7f27c26c92f   300000          1.0
#                                        1ht 6cb3cf1291c0a186d4d1ed254c0e5b95f8498bccc814d583fbac1baddebf86c0   600000         23.0
#                                        1ht 9977fcf096a81795abeb0829760e399a0a7a727ebf8bbb2f975a66dbac3c5326   700000         22.0
#                                        1ht 9977fcf096a81795abeb0829760e399a0a7a727ebf8bbb2f975a66dbac3c5326   700000         22.0
#                                        1ht d0d06e9bb510f55e1e26e25cc8e1f6dfbe31384d3864a5bbb5bf7e3c3a21ebc7   700000         22.0
#                                        1ht 7c695fce8378386ea23a9ed3e70aa346c55989885db26aa595f9b47f8299b8cb   750000         21.0
#                                        1ht 6eb6cb9918e8eceb347c37797a75e08f94c2050b857258f10609799502151a83   800000         20.0
#                                        1ht 05896b9e35cad01ba3b06cfeff987bc11cea7dad009e007cedff31d6b59a2dd6   800000         20.0
#                                        1ht eb213c0552effd7fb139395c7838edb8d59773a1cb57a00ddeac0e4885fb302a   800000         20.0
#                                        1ht 158e0bba9db45a85e623c23b5c66d16e5daadcc8d0e4b455ff5531f9ebf6e3ce   900000         19.0
#                                        1ht de2a030e1a81aef348a2f1391c24a5d54987f3653f4daf641d4f14ef9342446b   900000         19.0
#                           1ht wzleuinitszf 757e5f9a0fff2f3adf91cbd4b5453e64827913f6ce0faaff44827f473786bf93  1600000          1.0
#                           1ht wzleuinitszf 5ec6ab2e3edc8a98335f95115349adea6ab87ff8f63f57600b81ed42df397f0d  1600000          1.0
#                   1ht wzleuinitszf jvw nwc c0a2036ad13336dcc65836b0ef7b36986aa7bd75110ea6e62d7f0a35a279a6b1   300000         15.0
#                   1ht wzleuinitszf jvw nwc f275ee4a0469e877c6fcd4b25286acf8ed1ca3942f119b69dd12355d35543f9e   550000         14.0
#                   1ht wzleuinitszf jvw nwc 05fc99b64d99e8bdf19b2393a119a03a6cb5eec0c7b91bd59e219cc165a46310   620000         13.0
#                   1ht wzleuinitszf jvw nwc ee8073291cc6b4a683bfaf3245ea92d50d6f04c733be1251c3a497bc8a90369b   800000         12.0
#                   1ht wzleuinitszf jvw nwc 31d074dc51e6fabd2a235c23a3d9ae0e3702cf78f270e921dfbe2bfde289c2d6   800000         12.0
#                   1ht wzleuinitszf jvw nwc fa47945c28c3158ec03f9f1d03355aaaacd1a0d63bf81485a4838e2befa79ed0   800000         12.0
#                   1ht wzleuinitszf jvw nwc 31d074dc51e6fabd2a235c23a3d9ae0e3702cf78f270e921dfbe2bfde289c2d6   800000         12.0
#                   1ht wzleuinitszf jvw nwc 769732182a1cbce00527a7d93f9713fbc6bfcfb25f1dcb41825f66b3441547b7   850000         11.0
#                   1ht wzleuinitszf jvw nwc 4c1e4fa4b2a7ef873e1f2b7104790a2b85aa51cae545853bf835818293e5f118   900000         10.0
#                   1ht wzleuinitszf jvw nwc 5f821fa27f668fbc116b4186ab539ee438bbedd850fd2519defcf93df25fc335   900000         10.0
#                                     1osvzw 91d4b2b223e5f52168047c00c0d3aa0247f49dae3f77acc485f3ac723ec3e32f   500000          1.0
#                                     1osvzw 91d4b2b223e5f52168047c00c0d3aa0247f49dae3f77acc485f3ac723ec3e32f   500000          1.0
#                         1r ozwksn uzwmiorf 43311e971a037d83c1e8723ef51cbcbde602b6a73a0e3921fc80306da6712f59   200000          2.0
#                         1r ozwksn uzwmiorf 91944b6746db42df694ff532a64bdfe8aa498673565cb686ad110a48b70ab222  1200000          1.0
#      1rifhif jvwnwc  gnilrleksu wzleuinita b675d8eaf152a54c06cc324167b2657d42ec481b82aaa8e318197c5cdd644a93   850000          1.0
#                 1rifhif wzleuinita jvw nwc 747e39de2a4bf7ad216d696a79f2a1972fa95900e92c57506b5b162baa84d7dd   700000          1.0
#                                       1tzu 3dddd88f7d7ac6ace0dfd4927d881a9d452a3666c692bf2d392410c50e8d15c2   400000          3.0
#                                       1tzu 7e198b2f3bd2df5269da7d89989d3db0e6fa51f9df7395d643edec642bfa7e28   600000          2.0
#                                       1tzu 8bfec0e91b24c80e064abaed42bb61224ad9dcfec969306752181d8dec8863cc   800000          1.0
#                    1tzu jnkwbioh findwsiuf 1e31ece893aa0130667b352295d1230c406a05661d4885537ba120967797f6ed   800000          1.0
#            1tzu jnkwbioh findwsiuf jvw nwc 4f4d3137aebfdc15fc4626314308ef082fd2dde54ef9f17fda9e18dc7ea3188f   500000          1.0
#                                       1wkg b133539f72abd982f0ec6128a1c3120533bbd1aa77c583fc5525d035c1567341  1300000          2.0
#                                       1wkg 864c93fc39d3ef62b3d1e382cb10451b6fb2a3906934c6801fc4f6fa034e92d9  1400000          1.0
#                                         1z dc4b81f9db0d93a39f683a6ce2630faa67153fdd459bc8fce70fbed71517f62d  1900000          1.0
#                            1z subi jvw nwc 7c6890f084f8048684a1459a807c2b302a5573499193fbae29b2bae73f980c56  1800000          2.0
#                            1z subi jvw nwc d3909c7e26d7ab46d9147b0076302a3e7111c17b57b9c673100f0d3c583fee63  3800000          1.0
#                             1z subifafwzhf efebd085d90d6709a561fa94f2c0b01e08fd342bda5594e9873917247368a24f  2750000          2.0
#                             1z subifafwzhf c659650daaf7f10c6c6627b33627b4c7749892cfd941d0a6a652d22366105438  3300000          1.0
# 1z subifafwzhf  joicdlw gkfzc iotkusqkwsiu 9745e7a5d4f2532a25d8f658ada7393df31bfba9b344b498d0acd5fbc7951da7  1839999          1.0
#                                       2005 b289df59cf22bedb5d9ac19c0950d50a6d83f3bd7d84a5f93bf269e96e8bad6a   800000          1.0
#                                       2007 e5fefeec5cd524e781a3b70c20dca68387bd1ee2ede61cd5488831f59cc83958  2200000          2.0
#                                       2007 ab9e67db616193863355abb465dfc27ebac957234a50dfada51729a54f8d5fda  2300000          1.0
#                            200ir findwsiuf d3125a4c72e2f734573c23ee2d456df6ea40a203825373365f320f5f8676bc2f   750000          1.0
#                                       2012 6c1baa502c24694362e0f35713d1a9ba199430c0aaa7b60ccd9f62af77e5896e  1180000          1.0
#                                   20132017 516391bb7f03467d2b9131e9bfc227e3f4df0b3a1fb548ecb380a5d9abac8b12  1200000          1.0
#                                   20142018 7da9646f60f7e3e272deb8404fe92dee33909455fd83eaad633e173c7520beb3   300000          3.0
#                                   20142018 7da9646f60f7e3e272deb8404fe92dee33909455fd83eaad633e173c7520beb3   300000          3.0
#                                   20142018 7da9646f60f7e3e272deb8404fe92dee33909455fd83eaad633e173c7520beb3   850000          2.0
#                                   20142018 91221a92d3e60515fa97f120ba3f13bdbff7fd54543c55e885d80dba8e284faf  1400000          1.0
#                                       2015 94b046e650d38b02467c71652a873ba87c2aed541eb475180faef8b630ce573c   500000          2.0
#                                       2015 94b046e650d38b02467c71652a873ba87c2aed541eb475180faef8b630ce573c   700000          1.0
#                                     201518 b4b1ff6cd4061ff159141f5a5019fe5fe9e89b4baa313982548f4fbc27788cb3   200000          1.0
#                                   20152019 811c78a507b093aa1c736def6996fc3132fac1ad7d484081897b1e1441022d9d   450000          3.0
#                                   20152019 eb3c4f38089eade8a4fb0bcc9f787607e79c0a8c6b47f04e600ee84802a1059e   540000          2.0
#                                   20152019 eb3c4f38089eade8a4fb0bcc9f787607e79c0a8c6b47f04e600ee84802a1059e   540000          2.0
#                                   20152019 482bf44a26d01aa6e8313253f8956ea8cc2f2206be930793e312461604666873   900000          1.0
#                                   20162019 66c59b6dad047990896dc8171c3440d46ea59cabc78cef1a2cafa71d15024845  1400000          1.0
#                                       2017 03b2ac96f3c199bcf9a5b4176d63750cd522cc315537a2f66cc8e86b2b64d7ef   380000          2.0
#                                       2017 59e55425c5c878bc984e046f7664ca70e4d0df93bb21f05027f9d33fe6217325   500000          1.0
#                                       2018 175a0bf3f0952e59a6280c192b74e1cffba94f9224850a3208a4b0d213ada6e7   300000          4.0
#                                       2018 1659f25e0039fd0ff6ee8201ffd18843b75328a2f19372943363e777b9483457   840000          3.0
#                                       2018 cafb2f0e36abae18894aed29d2c75900889628e0926b04f633c2226471947df3  1500000          2.0
#                                       2018 e98b396e69f93078011e3d4fc85be086645adf35505b4ccb02aec0f25b8c4b4a  2000000          1.0
#                                       2019 4c28cfd63da949d4203c0dafc8c45e4d7b1ca7df272abb462ee17386ae51c171   300000          4.0
#                                       2019 1c5d731e88d0d583cf17a568c198cc0fe09d57c6375eb64033c5d1a6ffd0e254   780000          3.0
#                                       2019 76041dd3f787b6997c37d46adb929ecce39e5af7c5f323e021872e23ac5162da   850000          2.0
#                                       2019 dc0e39ff480b2c13e31ac21aa09cc943c16c5478f7cdaa2f2887a1fad108e90a  1000000          1.0
#                                       2020 df0652bad1b8a46bc63394e69e1b24d70ce092dc56243c343fc5b5bff6081843   700000          2.0
#                                       2020 79349ee45ced3de32f7286bbdaf0e27c9085245514f300c1944a3499d4488aef  1700000          1.0
#                                       2021 9adff2ce2e9971d5e5735be512c8a3bdb08ba424879deb5513ec5188af4bba14   800000          1.0
#                        20hzc hzcsk jvw nwc 6bae9ce78c9a27c257ead8b4da825f04915bf7c9d3a62b65b26476c8576512cd   560000          1.0
#                  21 lzuwf findwsiuf jvwnwc c68709a1c721ab6b2fb9fae63592acdddb8d027dd6da356428e5ef7e84347dd8   720000          1.0
#                                   21 uiowe a61931c880394376e7c6d47836c6fc12e3e1da7dcf9f227df298484371942163  1080000          1.0
#                                    21uiowe 80edc8631fb8b15792240695af5cbfdb78c265a0b1f785383f887ec737673686   472000          3.0
#                                    21uiowe 24fe4e29fca446e1a45ab7e359cfe6d93042c992b42116d5b5ba84b4508b727a  1051000          2.0
#                                    21uiowe 2b7ae74ee94a8591ba800108f0ede046df8cac393cb6d55d41f7d3a33fe39492  2000000          1.0
#                   21uiowe zdoij kffsfwkulz 28b3856b06d99d8869a3f51b9a39d78b7df1d1e25c9880dff983503cff9203ad   550000          2.0
#                   21uiowe zdoij kffsfwkulz 7e78977842e73760b825f20d737a36daa8b3f89dde5d0f7991e0848cc2c6bebd   627000          1.0
#                    22bzzw wosgkn mioncmscz 14a2e1fa82c002c89ad86b4ec37d40a00747f573341108405c2bd7fe15d55a9a  1170000          1.0
#                           22hiwiof jvw nwc 298884de565fe7e3c898647dc949170f323e53a2813822e9b63b0e92339f4b77   620000          1.0
#                                   23 nkref 7ba8fe64bbc18531f875ab5e50bb4fa60f8825cdfa836d5505c0d1515ca02c8b   500000          1.0
#                               24 fzvzu sul 2015948fdc550c2b45c3816f8553e76a7a55e32a33d01c4fda872ae4e4fbe303   980000          4.0
#                               24 fzvzu sul dd209a8b4616576d23c8efecfa5c21d473b15023ed27c74b6d76f694c6aac124  1550000          3.0
#                               24 fzvzu sul 6a343d591eeb7c073314934b0c572908d82784909e712a862fd8db665856827a  3350000          2.0
#                               24 fzvzu sul 061e5cc368e5235c17beaeaa687211b12b23676e77ad38dd46817b569e81e496  4600000          1.0
#                                        247 0537c751017d3eb9a42ce2483e53144cc22bbffb0c83d19713f4c6c7ccd0bbc4  1320000          1.0
#                                     247 kn f33501486008d15473dc6621a5ddee62f7e0643587d1ae7c8affa71e020bf78b  1500000          1.0
#                                     247 ks 6f0e6a071f07746754a040485ce7c14304f3ea9047a2199de3f9fc78d80c7ec5  1100000          2.0
#                                     247 ks 1e279e691c8032f3a1009bfe6cfc0e36b96f87ba375d0a3e774cd34bea8b4b22  1380000          1.0
#                               247 ldfwihzo 91ccebb4c4311a8bb648af2cb5f71c566deb0cdd251f0bb25073edc751cd9f15  1250000          4.0
#                               247 ldfwihzo 22047fdb74b72580d3a2f5753b25d146fc5f471a7f41e98377f43e6bb6af406f  1400000          3.0
#                               247 ldfwihzo 54056fe3b388c9ea40da97d778df88bc004648d11e0d1acca00bb460d7167756  1700000          2.0
#                               247 ldfwihzo cba67fb984e9240361ad5dfe18db550ecdd2713b0fa0d0f3ba748a5bac7cea39  3300000          1.0
#                   247 ldfwihzo josvkwz nwc 0805b6ddc1b8f7c94f0571dcec4cb16637550c4cd14b4dff4c17a04c4a379946  1600000          1.0
#                       247 ldfwihzo jvw nwc aac615cd8c22f723a75004bae26a7b4f9bd08f0ef554336d69dbc6dca6a64e25   640000          2.0
#                       247 ldfwihzo jvw nwc c7706b5ec87157873edad07231d223095f72021567d9d47b1bdd888b7dd177b7  2900000          1.0
#                                   247 snkg b1663a82e2f63de6d9e9c4d504bc385563893ae07c28be57300bbb1836dfb27e   950000          7.0
#                                   247 snkg 5121f5ec4d5581030bfc81fd01eb0ae5ffe0b6f54c8a52810ef26454fcccad88  2000000          6.0
#                                   247 snkg e0bb5e6c95f28b3d73105a8c04f88787c2ed876bd95f2e346d5cba6d749af168  2000000          6.0
#                                   247 snkg 86cd116574b7acfb3fd19d857686f0a796a3e9bfee4367723b5d456817e92cd3  2000000          6.0
#                                   247 snkg e0bb5e6c95f28b3d73105a8c04f88787c2ed876bd95f2e346d5cba6d749af168  2100000          5.0
#                                   247 snkg 5f1bdaedffb57d27b47191f75c06927df5240525587031d8bc7a337d3517bae4  2360000          4.0
#                                   247 snkg e959c3dae7a03c57d6bf03d299e623be9f7e736184788bfa01602297e9b05b80  2500000          3.0
#                                   247 snkg 55d9090a18ad38406af297ba5d455e3613441e2d8cbba9f3bf65184aeb185ce5  2700000          2.0
#                                   247 snkg 2c5d56ca7c6162c762e2938b8b11a5956861f530cf76ce963b13b507b61c5699  4600000          1.0
#                          247 sucsk jvw nwc 76e9d9e9ac43f162ffb731d84041f3afc96c612c4c2bae0172ce967e38174ebb  1200000          1.0
#                                      247ks d7a658319b664631f47bdaf885d2c8e7530e490d03dbea40c7360d24947747b3   200000         44.0
#                                      247ks ebb5c91ff863ddd55362bc30757a9c91905372e6892a68199c334d93b8dd925c   240000         43.0
#                                      247ks d0ba44338fb0b3c4f858f1c9bea75127cc766286fb1180fd8ebe397ae5c552b4   249999         42.0
#                                      247ks f225bb3d303b092598b41b6a4565b5038b2ec3d9694d9e3f69d18cf9e4d6bcfc   280000         41.0
#                                      247ks ef0fedd0e481eabb581158720499d2cc52895f2d6bb2853149696ee7e7771a1f   300000         40.0
#                                      247ks b2eadeefd1f8dc945ec3be18b6699cea2d90cf9f8b4b55c50458e4f31770c3e8   480000         39.0
#                                      247ks f6ef4a4cf061256d73eb734f6c6342e036495524d7f4bdcfb2d1ce3e3b86e82c   500000         38.0
#                                      247ks ffd715bb49f59f85b052c7ea6085cc3885f166f3aa302672ad6ce7a44e0c874d   500000         38.0
#                                      247ks 7f11d5507c41e57062cc46e055a6512a0fa894eaee31dda25d8e6932fbac2430   500000         38.0
#                                      247ks 790a618a2939be90e61e9ab156ef408720c859360caa780e262e401496acafe3   525000         37.0
#                                247ks snkgf 7a178d96a691332049263dc44cfa1a0eb967f173168d2c97bfb7572d56804a06  2200000          1.0
#                      247ks suuivkwsiu nkgf 2261a5c0cc94a72ed0de408521f01bda7b4754c2a4df5416d59619bdee458a1b   900000          1.0
#              24iunsuz wzleuinitszf jvw nwc 05d3a4631597652f58df5a25ece54a67014adc8ab914bb409acd130e2dcb4630   930000          1.0
#                                        24t 520a8c775f014720fbda49d899b70199ffafce40fb2759c97c9d7f63765cfb2a  1000000          1.0
#                                       24y7 5e5c8c58d45187f76cd20d7975b8745da0b87edec6e02efb7b76f87aa293c957  1050000          1.0
#                                        250 6f5b3ae9ce591f3eafa4bfd89ce822ed80137601492621c9706953e718d6b21e   520000          1.0
#                             2g suuivkwsiuf 81cc4154ebd697af7cefcec0279f6235de4bf30962dd0fb772e965705cc0b29b   960000          1.0
#          2hjimzo ezknwe hkuktzhzuw jvw nwc 1c7078c1a087551c574eaf77fa4f9ee1754b7a41d4350e632fe2d2d31e456943  1750000          1.0
#                                   2hzz nwc 663caee1a1822131883cd366668d1bad4d99fa7ce47bf8d42b9a733bfac3eed6  1019999          1.0
#                                     2kcjoi dce15e06393e442131bd74d371dca0975d3871cd3cd92f54bf7f55b0de44a7b2   500000          2.0
#                                     2kcjoi 080ba3cadcbd5ba1cf77a1f99e51c17e3f1b6819d1452bb03c6bbb75b586f2d0  5200000          1.0
#                                     2kcjoi 080ba3cadcbd5ba1cf77a1f99e51c17e3f1b6819d1452bb03c6bbb75b586f2d0  5200000          1.0
#                   2lihf liufdnwsut jvw nwc a845ae760a20b3b510b496dd340bf8760d40c405ceedd8d044cdbb43bd4ce51d  1100000          1.0
#                                   2tsf dkz 364a95b5d35dbe5a35633dfb911af310774774ae2b7fb78beeabf99748046da0   210000          1.0
#                                     2tzweo 7350cabe5541661c49b23aa435dbcf3ece972cb6260a888f8c3b4c1ecb476896   600000          2.0
#                                     2tzweo 7350cabe5541661c49b23aa435dbcf3ece972cb6260a888f8c3b4c1ecb476896  1000000          1.0
# 3 l nitsl   lnidc liuwklw lzuwzo findwsiuf e918011437c688b95d6ab90f6c2ec2d40868cac3d3a2c1f13e8b3cdc5b1a4a2b  2650000          1.0
#                30ckaf wzleuinitszf jvw nwc 36a271bf5eb68878ea2cad912f5de7f4b5ae1387b3c625a4bf4ea9623c1625fa   220000          1.0
#                                   314zlioj a213e56e70067aebcbc1f4e83e15b96430e983c52b7a265efd1a0642425b2032   600000          1.0
#                           360 cztozz lnidc 329df46a93da0a74ad0c03ef25fa0926ad9777a819896fbf6c0fff072d788e98   900000          1.0
#           360 cztozz subi caukhslf jvw nwc cfb2b6499ab8d0fce010958d7116343049f09a7bee36e6ec3f5ac4f3a7a9dc52  2100000          1.0
#                                  360 gawzf f058b7859e0039f3d37c60875679c2db64742b3cce07035bf4cf5e915e139f66   550000          3.0
#                                  360 gawzf 89dd8913ae308bf28952cb16828c645e7ceba8f39a07483b6621e5f5087b1ebc   890000          2.0
#                                  360 gawzf a5e7789d18842d3cf797568ed61430e4c07fb1d318450bce93839e3d8ee99ee4   900000          1.0
#                                 360 nitslk 5ae245cc56dd304501811502e54a5a5a8d03bb66d1c36e63a486651da8d8521d   700000          1.0
#                               360 ozknwiof e95d9544628389872062cee0a69f0132cf0a59694cf308f1c7293191dfea8f47  1055000          1.0
#                  360 ukdwslk wzle vzuwdozf 26370a831eb8fdd7beab7026801cf8c9905b87323c03cb4b4e29834da222646e   710000          1.0
#              360 ukdwslk wzle vzuwdozf nnj f705a41bf054d4c421f643a41ba0f37ca2a06201043b62e8d19b38dc1bd1dff2   630000          1.0
#                                3bokhzf nkg da01ceb0186db1af70ea85c26fb133abb034fcf3803374dc0c8f7fba90ba0a81  1050000          1.0
#                        3bsvz8 wzleuinitszf 44b5a1392698e847bea1cfe5fb69224c9c3035d68750e917a7d73efedb0c7487   800000          2.0
#                        3bsvz8 wzleuinitszf 134184c311db33c075647940c46362aa6e0004db3d47827990a72428f5704a8d   900000          1.0
#                           3c nitsl jvw nwc 4d0a0e2423665b0a2892835f0f8b42ded7abf672989050cf3f0e068ffcd636f1  3000000          1.0
#                3cjnh fibwmkoz findwsiu nwc d03c120b4e30b829bf1cff94269cec6741d1d1d8ade841a16b5d983c67c7744e  1300000          1.0
#           3cjnh fibwmkoz findwsiuf nshswzc d00167d33af0a49868280224716d61b5024ff8234880b04712bfa6d732f7a17a   340000          6.0
#           3cjnh fibwmkoz findwsiuf nshswzc 5013dccea25f1e95dab528f9fec7c6bd375a27da8c08745e9e103d8fca8b16a6   400000          5.0
#           3cjnh fibwmkoz findwsiuf nshswzc f3ae89e6840b39dcb982408feedbd385f73f768da2980dd5577f131e1942f17e   450000          4.0
#           3cjnh fibwmkoz findwsiuf nshswzc 801ab9d5949dac2f67832b10f6122bd1a0f978ecf6fe2a9d9ed7f4ca2a37d721   540000          3.0
#           3cjnh fibwmkoz findwsiuf nshswzc 3a068981a8897d08b2ae7432b9cda078a1b4caaf4b0cde25aacdccfc791076fd   900000          2.0

# %% [markdown]
# ## Conclusion 3 : Top 10 employees of data science in each company earning more than their peers - Class 1

# %%
df_data_scientist = df_mrg_ctc_sorted[df_mrg_ctc_sorted['job_position_clean'].str.contains('data scientist',case = False, na=False)]

# %%
# For each company, take the top 10 earners in data science

top10_data_scientist_per_company = df_data_scientist.groupby('company_hash').head(10)
print(f" **** Top10_data_scientist_per_company ***\n")
print(top10_data_scientist_per_company[['company_hash','email_hash','ctc','job_position_clean']].head(20).to_string(index=False))
# Out:
#  **** Top10_data_scientist_per_company ***
#
#                    company_hash                                                       email_hash     ctc job_position_clean
#                  10yks nzkousut 48be30753b1dbf2c2fccf43b7f45c51d68bb5725f4ae764fe457adb66df350af  400000     data scientist
#                             1ht 6b01808bba4c2d50258b068274232251620630cb252a9c09804ea9f7bbef4d8f 1100000     data scientist
#                             1ht eb213c0552effd7fb139395c7838edb8d59773a1cb57a00ddeac0e4885fb302a  800000     data scientist
#                            1tzu 3dddd88f7d7ac6ace0dfd4927d881a9d452a3666c692bf2d392410c50e8d15c2  400000     data scientist
# 1tzu jnkwbioh findwsiuf jvw nwc 4f4d3137aebfdc15fc4626314308ef082fd2dde54ef9f17fda9e18dc7ea3188f  500000     data scientist
#                  1z subifafwzhf c659650daaf7f10c6c6627b33627b4c7749892cfd941d0a6a652d22366105438 3300000     data scientist
#                    24 fzvzu sul dd209a8b4616576d23c8efecfa5c21d473b15023ed27c74b6d76f694c6aac124 1550000     data scientist
#                          247 ks 6f0e6a071f07746754a040485ce7c14304f3ea9047a2199de3f9fc78d80c7ec5 1100000     data scientist
#                           247ks 9d2537610d57179230806bb77258f63c3134b8fde9aa3afc06f626a8097660e4 2600000     data scientist
#                           247ks ddd9683a58865398ed934ee7faeb0825e515f2fe3cdaad2de8179e49b8030cd4 2500000     data scientist
#                           247ks c35054c043f6a02da3e6f142fbcb095f8145eb521137ffe753c952b103aed33b 2150000     data scientist
#                           247ks 5f4b52a1c2539fe2e4b29a8470bc57dbace331b819a0afdecc33f285ca397cd4 1440000     data scientist
#                            3nix a372713f7d18e6f03b5b469cbd1ddb8145c2688597c52845ea633de5cad114ad 1710000     data scientist
#                            3nix c27536d2fe174089c62eca78e6e643baef88a6100c14047998368247ad0ea3ef 1500000     data scientist
#                            3nix 5c67aa9b1414eb0dc68b6acc70c978f0b429e1f24f32a9bd16834c3503c0f63d  800000     data scientist
#                            3nix 24db964005796c656431df0b035768e8b9cee21f8cf42572aa0befe5e589d431  600000     data scientist
#                 3r wzleuinitszf af617ba27ec944771314f1c2d739b8208d2b3337800f8fc6e8ce4413ac4acbe0 1800000     data scientist
#                 3r wzleuinitszf f3b1e96456ad8a7d9cceb3901d763252ea2f56eb2ee7f4048f83e5c954df2395 1200000     data scientist
#                 3r wzleuinitszf 583a9600d8e74d5f3f6627da6b4ff3c466bf5cfee5ae9ff37ba56f547cde7e70 1200000     data scientist
#                 3r wzleuinitszf 89901f32acc07b5ca10c4ee5a9afda6de831cb84a0cbeb8f879d1b487d028c34 1000000     data scientist

# %% [markdown]
# ## Conclusion 4 Bottom 10 employees of data science in each company earning less than their peers - Class 3

# %%
# For each company, take the bottom 10 earners in data science

bottom10_data_scientist_per_company = df_data_scientist.groupby('company_hash').tail(10)
print(f" **** Bottom 10_data_scientist_per_company ***\n")
print(bottom10_data_scientist_per_company[['company_hash','email_hash','ctc','job_position_clean','ctc_rank_cp']].head(500).to_string(index=False))
# Out:
#  **** Bottom 10_data_scientist_per_company ***
#
#                                           company_hash                                                       email_hash      ctc job_position_clean  ctc_rank_cp
#                                         10yks nzkousut 48be30753b1dbf2c2fccf43b7f45c51d68bb5725f4ae764fe457adb66df350af   400000     data scientist          1.0
#                                                    1ht 6b01808bba4c2d50258b068274232251620630cb252a9c09804ea9f7bbef4d8f  1100000     data scientist         17.0
#                                                    1ht eb213c0552effd7fb139395c7838edb8d59773a1cb57a00ddeac0e4885fb302a   800000     data scientist         20.0
#                                                   1tzu 3dddd88f7d7ac6ace0dfd4927d881a9d452a3666c692bf2d392410c50e8d15c2   400000     data scientist          3.0
#                        1tzu jnkwbioh findwsiuf jvw nwc 4f4d3137aebfdc15fc4626314308ef082fd2dde54ef9f17fda9e18dc7ea3188f   500000     data scientist          1.0
#                                         1z subifafwzhf c659650daaf7f10c6c6627b33627b4c7749892cfd941d0a6a652d22366105438  3300000     data scientist          1.0
#                                           24 fzvzu sul dd209a8b4616576d23c8efecfa5c21d473b15023ed27c74b6d76f694c6aac124  1550000     data scientist          3.0
#                                                 247 ks 6f0e6a071f07746754a040485ce7c14304f3ea9047a2199de3f9fc78d80c7ec5  1100000     data scientist          2.0
#                                                  247ks 9d2537610d57179230806bb77258f63c3134b8fde9aa3afc06f626a8097660e4  2600000     data scientist          8.0
#                                                  247ks ddd9683a58865398ed934ee7faeb0825e515f2fe3cdaad2de8179e49b8030cd4  2500000     data scientist          9.0
#                                                  247ks c35054c043f6a02da3e6f142fbcb095f8145eb521137ffe753c952b103aed33b  2150000     data scientist         13.0
#                                                  247ks 5f4b52a1c2539fe2e4b29a8470bc57dbace331b819a0afdecc33f285ca397cd4  1440000     data scientist         20.0
#                                                   3nix a372713f7d18e6f03b5b469cbd1ddb8145c2688597c52845ea633de5cad114ad  1710000     data scientist          2.0
#                                                   3nix c27536d2fe174089c62eca78e6e643baef88a6100c14047998368247ad0ea3ef  1500000     data scientist          3.0
#                                                   3nix 5c67aa9b1414eb0dc68b6acc70c978f0b429e1f24f32a9bd16834c3503c0f63d   800000     data scientist          6.0
#                                                   3nix 24db964005796c656431df0b035768e8b9cee21f8cf42572aa0befe5e589d431   600000     data scientist          8.0
#                                        3r wzleuinitszf af617ba27ec944771314f1c2d739b8208d2b3337800f8fc6e8ce4413ac4acbe0  1800000     data scientist          1.0
#                                        3r wzleuinitszf f3b1e96456ad8a7d9cceb3901d763252ea2f56eb2ee7f4048f83e5c954df2395  1200000     data scientist          2.0
#                                        3r wzleuinitszf 583a9600d8e74d5f3f6627da6b4ff3c466bf5cfee5ae9ff37ba56f547cde7e70  1200000     data scientist          2.0
#                                        3r wzleuinitszf 89901f32acc07b5ca10c4ee5a9afda6de831cb84a0cbeb8f879d1b487d028c34  1000000     data scientist          3.0
#                                       3xs nkgf jvw nwc 9fe51e408e203fe5cd6dc27bac9832a58dc19580954308ec1bb3372b85dd863a  1850000     data scientist          1.0
#                                                6lnslrf ec0e66771faecdc6bde11bfa89022cf76ff07884bb3400c2148a01fbc3586614  1500000     data scientist          1.0
#                                6we zuzota wzleuinitszf d15ed3db039ea786a3eefa496465a74e58d8e969cc7e94e17aa7ad7e3fa73699   500000     data scientist          1.0
#                                               adhjsuti c903e9576f86fce5ac8ca7db582581fb8b66dd369a1aed84b475e71413333161  1800000     data scientist          1.0
#                                              adnd gsrz 140f2a4a80ea923b472c06054cb363dbeeb931defbbb4967274f00757c93f890  1800000     data scientist          2.0
#                                              aidgiwslf e621b3eeeb33f8168bc7fc46bc7ae35b2fb2831fa5a47d140210e03ec11949a3   300000     data scientist          3.0
#                                            aidjndf sul fd97ee5909e0db824aaf15b5f293987a1c21272ecc491e5788d3fac9dd7b4b54  5600000     data scientist          1.0
#                                            aidjndf sul fe693198a836a33bb36ae893e6988acac0c4fc12f2e6691c5f6a91fe4fed8c03  1650000     data scientist          2.0
#                                    aidoimuoiih jvw nwc 17ffc11374aa99a8409a16fa299ce33165a07085f7112a6446954536d40f7066   450000     data scientist          2.0
#                                            aif zcdwzle 9850603e4b3ad0f63d28b4e0f4f4cc7e43e82dc431c90497feba296e9f6550d6  1200000     data scientist          1.0
#                                              akeii sul 2b0e61699f885bfe11790d5cd90bf102a85ff2a83d3cd0c6dedaaecef4fc55c8  1000000     data scientist          8.0
#                                              akeii sul fcc1579e2ce8f73d261f6321c0bc1badd5ffa30a9ab6ded6671967d468363eea   217000     data scientist         11.0
#                                      akfe wzleuinitszf 4b27665cbc70d3521747cb3871e4abd19f587094fbac914f442408a14ed4e710  2000000     data scientist          4.0
#                                      akfe wzleuinitszf 4b27665cbc70d3521747cb3871e4abd19f587094fbac914f442408a14ed4e710  1500000     data scientist          7.0
#                                      akfe wzleuinitszf eb51b309e1e7656976ef65785e9e2925f5098f872b9040cf589e41a93e9f2d96   900000     data scientist         20.0
#                                      akfe wzleuinitszf 1a60527ec58c82750e4e5ede78e09ffc1a17601b413b04c2a1b6fe5e7084b4fe   850000     data scientist         21.0
#                                      akfe wzleuinitszf 4ffb09322cb2b4de2c4cc5f67b863562de2278770f033620591752f8bcdfc099   850000     data scientist         21.0
#                                              akuwokrfe 472db591f26941e2ef65980e0144b661e66deafd908ae293969e98dc5ce04dda   420000     data scientist          1.0
#                                   akwok iunsuz jvw nwc 927d8e08ec4ba7fa0ce42ddf07920161cfdd4a7e50ae39708ef37f333c276611  3000000     data scientist          3.0
#                                   akwok iunsuz jvw nwc 028a67db0e61679da1f7d19176f96744bbefb24ac53d77b10f320649378d85d6   800000     data scientist         34.0
#                       awooz fibwmkoz findwsiuf jvw nwc 236ff58028d2ef63d550f4412abc245bcd819e0b45000971153bcf551e4a7ccc   950000     data scientist          1.0
#                       awooz fibwmkoz findwsiuf jvw nwc 3bee9ab6e730dd5006721cc54835247fa6f35e5eab38c985864b9febc9a80b72   300000     data scientist          3.0
#                                               azf gkur 7114600f76dab172b2efa6c464deb083426d1318f3c5aed112de50de944e6fbc  4000000     data scientist          2.0
#                                              azfli fon 0d37bf1c97c48c8bc70704dc72329f0a74a49e8fcf3c1186c834d1f0ed4ff26f  1200000     data scientist          2.0
#                                                   bauc 4b8450bbc16177940f697baf69baebd1a88c1802891e17dddeda9ccb2f293ec2  1000000     data scientist          9.0
#                            bdndwdok gdfsuzff findwsiuf 43369982735f07ae198034c7ef276c206ed32fd573b519ebf4cc7d544a09fb55  1000000     data scientist          1.0
#                                        bdnnliuwklw sul 22b1b82e8d15d39b88a55170229dca4f629df80450000d99830718e4103d846c  1200000     data scientist          1.0
#                       bdpswfd liufdnwsut sucsk jvw nwc c4438f718dcaa9928307a902cd87425ceb0064f7fbec0efc505d002dea19986a  1670000     data scientist          1.0
#                                         bdpswfd tnigkn 1da6626deb9335905b18b26127834898ff735aa270baee816056eaa1dd021719   800000     data scientist          8.0
#                                            bdqqa nitsy 0381327ce345b5892e451e714a600910ded426ba18ff549dd0989aa8a5ab0eab  2350000     data scientist          1.0
#                                            bdqqa nitsy 4f254a205d476eaf6f28e8e975bcbabc9452cc29222658097cfbc1e89cda351e  1250000     data scientist          2.0
#                                            bdqqa nitsy 9a0d03d56033a4a5713cabb578932a67bf897573d326da91a7ef42f6dae3f15d  1200000     data scientist          3.0
#                                            bdqqa nitsy cc0d880fc348f3e8ec2f40dc4c37035f74cf54e16c43a8771b2a6dd404c2318d  1200000     data scientist          3.0
#                                            bdqqa nitsy 9a0d03d56033a4a5713cabb578932a67bf897573d326da91a7ef42f6dae3f15d  1200000     data scientist          3.0
#                                      bdtzusl findwsiuf c67d011a9436abb69fddb83c4186e233778a363557e116b42b366edd96ef78f0   750000     data scientist          1.0
#                                         bducsut lsolnz 10f9827b8a89fe196e67517a6b22e61802b3579cc2e12cc795a22d7154fa606d  2500000     data scientist          1.0
#                                  bdwdoz bildf subiwzle 997a98ac86d0f9e2d74b5d53d5fb33c9b944a8ba647c2b21ed3cdad8d5f5efdf  1950000     data scientist          1.0
#                                     bdwdoz toidj sucsk 80630662eb93622b0aaee7d07ec515641a30f145094a9233b6f133fb9f9e8b2d  2900000     data scientist          4.0
#                                         biiwniifz nkgf c5d312cfd261683326d5e2c28f5ad6ceaeb4e6d5b28665b155d1808ac386805e   850000     data scientist          1.0
#                                        bildf zcdhkwslf bff667f51bfc2e533cb1b7aea5dca7fe2ff34bc7619aa3fa69e7d7ea974f960c  3700000     data scientist          1.0
#                                        bildf zcdhkwslf 260b37e1764fcfa55d15169c1a6570fc029ab2c519dfa39876dbb4b7960bbb18  2100000     data scientist          2.0
#                                     bioc hiwio lihjkua b9ddd31362a9eb891f78ad0cd0c082d61c2d3cfa77f826b23b68f85141094d5f  1639999     data scientist          4.0
#                                     bioc hiwio lihjkua c83fde465e35298e87b63f59d1a8d22cddf9b18daf8c94437175f329b9f0fc36  1600000     data scientist          5.0
#                                     bioc hiwio lihjkua c8fe25ce71e597e956a8dd4c8f097f35329682db88d53bc096e016ce9e6cc826  1400000     data scientist          6.0
#                                     bioc hiwio lihjkua f2cc42f17a0a443070b80746858d9fecea060c0f9b211fd72accca35ecc84c97  1300000     data scientist          7.0
#                                     bioc hiwio lihjkua 4c1fd169aba9eb0ef0a25cd31054bccd8adb347b05ab297f31ecec552c3b9451  1050000     data scientist         10.0
#                                     bioc hiwio lihjkua e6365abf306ede27f848bbb78b8398cce35c5573d7836e5e2b6bbdf3018986ab  1000000     data scientist         11.0
#                                     bioc hiwio lihjkua d1e218400888ec8622d8a68f48dba27b9ed08e540223bdb03485823848a261ef  1000000     data scientist         11.0
#                                     bioc hiwio lihjkua 9cdf67dc1ea079e15c23655e6e80af37eff089639e60fad390e6c625f16b6c1d   960000     data scientist         12.0
#                                     bioc hiwio lihjkua d86e159652ae039c7d2a3addebf29e60d96f139a952d3fb987100bc30a1d8677   650000     data scientist         21.0
#                         bioka fibwmkoz josvkwz nshswzc 0e5b0de549e5c3813cc2ebb354e185de9c2fcd8b3442b2b1c85f31a7848efdf5  2050000     data scientist          1.0
#                                             biolzjisuw 3a86cf2a8f663e72e821ab14c26261d5d8cf37b41c0ba4cfa568bea2f4faf304  6300000     data scientist          1.0
#                                             bior hzcsk 85fc57b4dca5534ef96f0e6158413643f4b00598536941dc42498650d9b576dd  1000000     data scientist          2.0
#                                   biotzkezkc findwsiuf 50ad97599e7d9b8f5acbd0f179f87aa076a8ccc4239e1561c0819cd092392e79   400000     data scientist          1.0
#                            biowduk zuwzowksuhzuw toidj edd7b78002ff89ed4f7ed231a70630a9ba61aa42bff809e78cf53a44f83ddf6d  1000000     data scientist          1.0
#                             biowz ozfzkole fafwzhf sul 97334c71b9c425e4f8706cb1929eeab37b9f3b15ac415a16d309f44a48d67454  1400000     data scientist          2.0
#                                                birknks 3a98a052b1a95fb1fc3256268992940b660c89baca9c39ff22257c9507d52a98  2650000     data scientist          1.0
#                                                biteiou 31ef1fa9b8148380d1a65b6971655d4691dfca2a674a682f3f5c520ddee0f772  2860000     data scientist          1.0
#                                    biteiou fafwzhf sul d6cd196967c7e9ca5feec7ec07263018946a9a95e5b236fb65c058bc54da4220  2000000     data scientist          1.0
#                                       bkgdnafw jvw nwc a2bc8fe7ebb58f35734546d77b8942e36ad7ce125d40c710a05b975d7c29912c   600000     data scientist          1.0
#                                                bklwfzw 5152e22ee68ac78ad5ad67cf9a477135281ade11f4ee26237311a2419ec045aa  1600000     data scientist         23.0
#                                       bknkgznnk ozwksn 88abf3ea46f1d9ebaa5eafd56554ef12ad1858faee490a68cf172c72335c9aa9  1650000     data scientist          1.0
#                                              bkohtdscz 2c47854df4262ba8afbe9837b467261fbdcd4adaa41cd0e38d75923e096adb3c  2900000     data scientist          1.0
#                                              bkohtdscz c65789bcdd1d3b7b8112b11bd1b3560717b6b832e3d98c0853c30545794c6e93  2100000     data scientist          2.0
#                                              bkohtdscz 870d2fb4234b678f73fd39f94261f4ba3cbec294ab8df28178573d50a383d452   800000     data scientist          4.0
#                                             bkozjiowkn 500173f5e68bacfa96eef54d5a4716ea05f8188decc6dc920f10e80d7e291a67  2030000     data scientist          4.0
#                                   bnaukvk wzleuinitszf 1e9dba751d4e32968571e5648395aeac09874d8372b89cd8f1e2f740c916d5eb  1000000     data scientist          1.0
#                                   bnaukvk wzleuinitszf 964eee18991f5ef6cb0ad12ca5f57d80e60a68207ea18c34d045e0137f0f1047   800000     data scientist          2.0
#                                   bnaukvk wzleuinitszf 462c2608dab7c94e1eee12df8b1780b30289ed68d08b300096dd21d9beaa6195   750000     data scientist          3.0
#                                   bnaukvk wzleuinitszf 84934dfd6cf09d0052b4513c8dfa3a84a2725e3f258c3c381300fa1b088ccaf4   730000     data scientist          4.0
#                       bnaukvk wzleuinitszf  ssw rkujdo 0660a48d99cda6e7fe5b53a651d0f7d9156762811821ee39ef89f2539fc5069a   800000     data scientist          1.0
#                                                 bnawyw 653ff46def093f51abdd107533e1b47dfe687dbf0e7357db5e70be6ad124a33f  1600000     data scientist          2.0
#                                           bndio ckuszn 3c393416ec040861801c66b497b76b6eb84c7214515ed205c0be778512129879   900000     data scientist          1.0
#                                               bndsc ks 7a716c316196dbfad834bb2cb5ab3ed9ef95a1fce64a1c9bbd0b9ac9e97c642a   450000     data scientist          2.0
#                                              bnsjfeijz effc03be965944c838555fc377aef161f8c1309dab10f3845b3d30aa9e50ac7e  2400000     data scientist          1.0
#                                              bnsjfeijz 1f67ac1df624a2a8047e55c79681ea3926ef0e523cf00a512800d6163a20ded8   600000     data scientist          2.0
#                                               bnsjrkow e9a4efdf9f32e7f062e05dcae4ed32751f8eecfd4b3c9d4be18c9c2ca514bcdb  4620000     data scientist         46.0
#                                               bnsjrkow a26cc532d9493ea0c191bdf771d693cfcfd8c8930e15162019943d6cffd6c8fb  4500000     data scientist         48.0
#                                               bnsjrkow 2db8dd24dfdf0f91042b1c5076f2c3e16211cbb6e7e16243856b15fc06dff717  4300000     data scientist         51.0
#                                               bnsjrkow 91048c7f01282884fa9c1ce8499ed4c4bdf05c87f35ab0f9e35d0e6780dd124e  3700000     data scientist         65.0
#                                               bnsjrkow 71dd396ef6049136a7321d549b117d91f4b3c2d1bc82ab6030c325319709e714  3200000     data scientist         82.0
#                                               bnsjrkow d6e0db35b751edf14d8fbe621481e28aab9df264796c24702252201c9f84023d  3000000     data scientist         90.0
#                                               bnsjrkow 96ab90af86726961e4d6a38a498b18fa5d5f90c8481b7229ca32b84e2a8f6f49  2400000     data scientist        120.0
#                                               bnsjrkow 2fd0a51b851a76343eca7b442ab0b61533eaced0d480f3b9b91c3968dd0d9323  2000000     data scientist        138.0
#                                               bnsjrkow 2b5fe3ba6785b09e816653d33fbf8f74bd81db31ffe790dc1cc1beeb2fa7b874  1500000     data scientist        158.0
#                                               bnsjrkow 7b93b9d3194811084fb81c2e4af3e0452c27561580f107984c71ddb260acfbde   320000     data scientist        199.0
#                                                   bnzy 0b63d41ed7b775cb06ef3362b1d9e4136de4112910e097bc769e86d71469d7a1  2200000     data scientist          1.0
#                                           bnzyiwoiuslf c618c5ba8db8035668e819a3f148fed952d5e420046f4f24e8b6c7cce13dac05  2050000     data scientist          1.0
#                                             bnzysnikuf 557efba9188faa38c021a8890c67af31053adf6f8a720595797de22228a39522  1019999     data scientist          2.0
#                                 boiiw ozfzkole jvw nwc 8c9b9b979b50534073309c1fe5a60eb78a44e70b8fa69b9189cdffe2eff090ca   400000     data scientist          1.0
#                                                boklwkn c7edf31bc521bfa410c35c11ea89a3eabaf5104d2307efd572f28c7a1a853003   900000     data scientist          2.0
#                                      boklwkn kuknawslf 8e2877ce33b2cfe575aad33e020ef52a3d38015c913a2829d869a266a6bc70b6  1250000     data scientist         26.0
#                                      boklwkn kuknawslf 7723cc2b380782d52dcd68cdf6da067d52bc8052eba05b6c1b7805e6ecfe27d1  1250000     data scientist         26.0
#                                      boklwkn kuknawslf c1996da06638bc2fe6d7f49e8cf27a6e36562385c0b0b97e11a0e232121e0990  1200000     data scientist         27.0
#                                      boklwkn kuknawslf 9aac07d3e91e353ba8726aa9b109aece0b0422dd44ce200e1513fb35a98fc047  1150000     data scientist         28.0
#                                      boklwkn kuknawslf 7ab7bdf965061c4114f0e33fc3ad3c12fb7986a6bb6165fcde438d5484e60304  1050000     data scientist         29.0
#                                      boklwkn kuknawslf 11256e3edb994aa01cab8b866ff742d486dc9105c6456237f5226576c143c633  1030000     data scientist         30.0
#                                      boklwkn kuknawslf 0425e184c4f62815804517bc0b474ecdc8e1f08ce09e6b722e4efb693e4dc119  1000000     data scientist         31.0
#                                      boklwkn kuknawslf 25d7cfaead47ab1b66302ef575762e4efe88e1095ed51c98e721474002b9ec5c   850000     data scientist         33.0
#                                      boklwkn kuknawslf ef705c5e953f251fd2ea9202f7f4a1485291c939d7c96059f05d2a958b3120f2   800000     data scientist         35.0
#                                      boklwkn kuknawslf cd611108510f27886f6f0bd1e8c9e5359a8359f58e13c92d17910e37fe1462c8   630000     data scientist         37.0
#                              boklwkn kuknawslf jvw nwc 78a4c1b1ffe0e958968f7d10393c6a8dc561245c75a43291c5fda82f99d98d5b  2000000     data scientist          1.0
#                              boklwkn kuknawslf jvw nwc e9e057d1c8295ba7748aeb7bcc389752df6c2852363b1626482090d4b46fffb8  1800000     data scientist          2.0
#                              boklwkn kuknawslf jvw nwc a96fa05daccdf3d686a2b86391c21f376990eff9906ad67d2128f2bfcc34f492  1050000     data scientist          5.0
#                                boklwkn zuwzojosfzf nnj 616afe9920395567bdda27fbf3fc89ec9dd25cfe5356bb9357984bbfc99040c4  1500000     data scientist          2.0
#                                              boklwknks f44060598b665d6be9604fdeac45b1bf116ac3773a4cea1d100c45952eea0cbc  2000000     data scientist          1.0
#                                    bokthk ckwk fafwzhf 43f071b9d6cc91cfe7e6286725b567a12a5c76228ffb66ba478286ed2a08f06d  1000000     data scientist          2.0
#                                    bokthk ckwk fafwzhf 92a2189f513a45bd2f99a6ea41aa87354eebc5c5b11f1361c310ae6ec2715713   850000     data scientist          3.0
#                         bokurnsu wzhjnzwiu suvzfwhzuwf 3cc98cb22ea2adee5465ad51600f48856f2503a76697fecec3771c9c06be9591  2300000     data scientist          5.0
#                         bokurnsu wzhjnzwiu suvzfwhzuwf 52dec0916251f5666aacac882fce9878eb693fb84bbe3135dd683285822ed5ce  1150000     data scientist          9.0
#                         bokurnsu wzhjnzwiu suvzfwhzuwf c233149a55bcc28298e488748685c74ff8757daf4ec95bec6788e81d9d6c37dd   600000     data scientist         11.0
#                         bokurnsu wzhjnzwiu suvzfwhzuwf 54866b706ceaab36d6e7de03fba8369aff899d49b25881b181626d4c851819c6   400000     data scientist         12.0
#                         bokurnsu wzhjnzwiu suvzfwhzuwf e5b26a2c07caab7fd025e75e61e342bfbc196a4f8e1b4b005a69c45639c533e0   235000     data scientist         13.0
#                               bokurnsu wzhjnzwiusuuivk cd6267de852ad472bfa2c3f819628324252d1dc0607340915303136692f87286  3500000     data scientist          1.0
#                                              booinz ks 9f7ef46ff1b2e31722bae8682c666ef803bfd3b1c7171abd554c3737d0a459ee  2300000     data scientist          1.0
#                                              bozfeczfr 30114f106f7bae664934c2dd948b06d67c5b4f56632aa4c5848935c3b082f984  3600000     data scientist          3.0
#                                            bozfeirkowq 6e3505d73abef588b86200cdd2b42184d396fd8a1198d20e6df6a2204fdd2c5b   700000     data scientist          1.0
#                                             bozfemiorf e263dbf45ce62b50aeb1971e8aad7cd8b49c415cdae0d3c5f7cad8503230d141  3700000     data scientist          6.0
#                                             bozfemiorf dbff7b6a9d52cf6eaf1249cf27e3ca735987301dbfc7af4c4a863faf6e753286  3500000     data scientist          7.0
#                                             bozfemiorf 619cc29eb172b54d39002273637b2c87babf1bb2d974590aa204c5e2a66953e0  2000000     data scientist         19.0
#                                             bozfemiorf eb5552cf683e3072a7e2e2c6e63ebb46183a716b2bd2a16be75a639961914146  1780000     data scientist         25.0
#                                             bozfemiorf a24b8507c09aa5d0e0b1d2e72cb1292eb07749f09b528fa9aa56b9ab2889cb69  1500000     data scientist         31.0
#                                                bozfezo be8afd4a4e5cedb6bfbabbc88f15e756d69c3f2491d02a529c1ca3439e3049f2  2000000     data scientist         35.0
#                                                bozfezo 43a4696a41a94144182189a0237bc9208ee1b695370812c8e54ce688acbe05b1  1800000     data scientist         38.0
#                                                bozfezo 428d05b2ca5c865a31eea4fdb53c00a2f23ac532b43df8d25c07d2fa2eb0c111  1400000     data scientist         46.0
#                                                bozfezo 929eb13ebbf98260c483a3d5b3a064368034c7c78cc37c400680db37aa55921d  1000000     data scientist         61.0
#                                                bozfezo 0cff17f2819db3b418576ee155e39b9d994ae05b3e19745932c8ac82df8cafd8   900000     data scientist         67.0
#                                                bozfezo 01c83c1b17566263509cfd8c5550f89f7eb0949ae2b4694fc36253588b541242   800000     data scientist         72.0
#                                                bozfezo 17d54b2e66dd45c17b1e5ed25e1fbddf845552ad77e370580424ba48ed12757b   800000     data scientist         72.0
#                                                bozfezo a6a8c9caa92c3df4c46f95a4e80d8e0d51f52a9b9455224789351ab3b47e6618   600000     data scientist         94.0
#                                                bozfezo 3afbd7317baaa41ab25ceb922a7e44e6e4405c66687ddfaeab690334e5c35971   400000     data scientist        113.0
#                                                bozfezo 32becf5902bfab82a78ee3f37704c39dfc1d28e7ffd8d055402acbb103efba0d   400000     data scientist        113.0
#                                bozfezo niirsut bio pig 9bed6127a2cbb994b24f1a5b1ae334e1acfb8c65d01e6c303cb07bbfaf88397d  1000000     data scientist          1.0
#                                           bozz nkdulzo 6a945671a5d8e7db041c5b10c51aa830d50d4969aa18ce9e0d0795b007784e5d   600000     data scientist          3.0
#                                            bozznkulsut 09725c4e6ff77029eacf1c4ebfba1fa438ea5055beed87bd4a9287565e82dd1d  1420000     data scientist          3.0
#                             bozznkulsut  fznb zhjniazc c932ed61ddfd4d0acb29c97401015ddca46282fb0ca5db4721579306feba272d   600000     data scientist          1.0
#                                              bozznkulz e212a1d959492ddb92f09dd29b280b283f8fa1d571717f68f7865763d8c81763  1910000     data scientist          1.0
#                                             bozznkulzo 43de71a5c575566ca942e42f95cf21cb83de7b2b832a6c3dba2afb20ab6cf755  1500000     data scientist         16.0
#                                             bozznkulzo 41baaf443450ad5710a3ea01129dc5b4b7174f5358f4895f331222afa5ed2cc8   400000     data scientist         42.0
#                                         bscznswa sucsk f69b4ebf00b4cfd46cd3b1165ec35501977decb0e045ae76db1610aaa8a1ffea  2500000     data scientist          1.0
#                                   bscznswa suvzfwhzuwf 3cb1a016820753306123925b9c1f3e60deb3e75c701df0256178a878f9dc6b81  4500000     data scientist          1.0
#                                   bscznswa suvzfwhzuwf 0b31ff37bfdd562c3f5e30751f52edab3777b96ec68cce0aacf0fc053c549e36  3720000     data scientist          5.0
#                                   bscznswa suvzfwhzuwf c94e4b31c6059ceaec44d1c9e304f42448902b3fd30db4b27f4d44cf36208f3f  3000000     data scientist          9.0
#                                   bscznswa suvzfwhzuwf 7392cae46f1bee51a1488be6aa763f3f16ca14bc224ce0bc08da6079a0158647  2800000     data scientist         11.0
#                                   bscznswa suvzfwhzuwf 2222dcf2e32781406f130f5d2cceb46e60252b9754e7e595132a97b259551730  2200000     data scientist         23.0
#                                   bscznswa suvzfwhzuwf dc5a5c6cdaa14cede992aa1acf59ca850723f9b241b5accb579d0859e9beda43  2130000     data scientist         24.0
#                                   bscznswa suvzfwhzuwf 9266398693c47b1aaea9444cb6372f1bdc2c463e9d12c1bddf0de78e3dac0bc8  2100000     data scientist         25.0
#                                   bscznswa suvzfwhzuwf 10cb73f2ecc5fafc1c0f10ea9e2cd34a7c4ca439cabc4843bbaf9bea7f6a4678  2000000     data scientist         28.0
#                                   bscznswa suvzfwhzuwf d226bd26c8743a649fab3a6bb17a3318fd896c8b4fd3f46ac83eb8e58ec43c11  1570000     data scientist         36.0
#                                 bscznswa suwzoukwsiukn 615a3b53e6e84f0ef750b6908bf0347beca213f69b734b9a32a2cf2b36c7d5b5  2100000     data scientist          3.0
#                                 bscznswa suwzoukwsiukn f9944d41dd83275bf175b6f05407daf0292f075390d303a9f79510a651d11cd0  1950000     data scientist          5.0
#                                 bscznswa suwzoukwsiukn 5d1e32b79d3bef1ebf803dba1f50db84b5261e547943bbc573c6f186083a04cb  1080000     data scientist         12.0
#                                 bscznswa suwzoukwsiukn cf729bf0432c45166bdd28445edc3eb6832aa5088487b1ed0f546f306796943e   700000     data scientist         20.0
#                                                    bsf 470930dded891a4d0dd208f5bf14d53b9893f53d7f57c15f6c47156f007a0327  1500000     data scientist         11.0
#                                                    bsf f7d89a91c05928b801ff4a54560cf99019b7ac89dd4f5bdd5bb4aa62f5811c67  1200000     data scientist         17.0
#                                                    bsf 5ef3f3fce75b7a444ae3ab34ee41fb050638f8b1650e87807b05c318c68adc0a   930000     data scientist         26.0
#                                                    bsf 70b52b0981b2394d98ec155401b046a09c1f62cd54eb7aa7b35434576bd54fdc   900000     data scientist         27.0
#                                                    bsf 4efe7eb1ec16c63cb3d92f28cbcc4678972417da4beeee9949124873850cd2d1   850000     data scientist         29.0
#                                                    bsf c0ae188edea261166ecd1415b80ffe08be7a166ffafc89050f5efcea21d35527   480000     data scientist         44.0
#                                                 bsfzov b9b97e5d19d4f6ed074a8adbc32576d8306c0f0b7b5a76e1cb86a88e6aa691f2   610000     data scientist         56.0
#                                                 bsfzov ac3009da28110d8668664c0789c0f2b0bddd2c63ad49ff20d707a3763918bc77   550000     data scientist         61.0
#                                   bsgoi zcwzle jvw nwc 23daf483ceee5234b79bf435804c57377c91a9e20afa95016db40fdb1b57015a   440000     data scientist          1.0
#                                               bsi nkgf ae5d329ec29918d0e437a0dc86d7541f6d8a5cbbc43778264cf1be252037ad16   900000     data scientist          1.0
#                                                   bsli d1290b7e2d85c75902b863ccc3e4aafdd6e6eb07a10a002e090c4fafc7c172ec 12000000     data scientist          1.0
#                                                   bsli 0ccb803809d85dd78169e732fdbf4ffcae5ee6d68db66265d8ac521e1961309b  2300000     data scientist         12.0
#                                                   bsli cbbf3f54142b858711a2719a8243304ae1d5c390e449ee509d1f1cc7e68a6622  1750000     data scientist         24.0
#                                                   bsli 1fc56396cdc5545d860b5e12fb3777228ba75c201d788f53d08941b4890824fe  1000000     data scientist         46.0
#                                     bsli sucsk jvw nwc 1dedf0175cb7ee16d355d5f374a9121a1c19ad1c87594c895d4c166109257a4c  1580000     data scientist         15.0
#                                    bslicz wzleuinitszf 0a39f31a0a649c10660c5f36e09bb9a12005d9feedfec35caf0374b51f006d92  1000000     data scientist          1.0
#                                    bsohzusle koihkwslf 1d21d6b064985b619b9aecc1b87a9f69ff8d7249c2580fa947fed37aad5f83e2  1550000     data scientist          2.0
#                                            bsozzaz sul 66dbaa510369c8db610cc21d0c88c4c3ae12c3950556354b068a078e6376926d  2000000     data scientist         16.0
#                                                  bsthc c5738f7e6443b57b67306ed648bd7e17a16c8a71cf093b2e49e467df458a838c  1100000     data scientist          2.0
#                                                  bsthc 4c18769188769e292de61879426a8c7d38900aee5be853ba3b389d95420edc7a   650000     data scientist          4.0
#                                                  bsthc 4c18769188769e292de61879426a8c7d38900aee5be853ba3b389d95420edc7a   550000     data scientist          5.0
#                                   bsuckgsnswa flszulzf e6f16e38c24b5111883f218e42cf1c5764e5fa3bff23f9ff0012e4703f3abf78   300000     data scientist          2.0
#                                           bsuhzlekuslf 5c191eafd5014b3c1c631e3eaaca30b4f7d701040f15cc17825448bb0224cc98  2900000     data scientist          1.0
#                         bsukulskn fibwmkoz kuc fafwzhf cb03b0d7259e906d84925bd464996e73d28909f777cf88883a90420530d75a1b  2100000     data scientist          2.0
#                                                 bsuqko 12559e2bd963e6840024ddbc9274faa8c84c7dd5780c6f7bd35c803e6958007f   300000     data scientist          1.0
#                                               bsuslswa 06fff372d11bf523c108971c2e53198bd571a3be96bc9cf8d31e321921f9ab31  3000000     data scientist          1.0
#                     bsuuivkwsiu wzle findwsiuf jvw nwc 9ded6d3e150042ce1270e2762328c7bf2ca44951a7997f4ef6eda78c353fd23f   670000     data scientist          2.0
#                                 bsuwozz bsukulzfwkowdj 7b46495b8560db97b8006b92e0861f7ba882a3126a470d01482798743ce07cd6   600000     data scientist          1.0
#                                       bsuznkgf jvw nwc f3bd77ca95b3472b77fc5cd3980be213bb8bd2fc2386abd7e641befc6c214a27   800000     data scientist          1.0
#                                                 bsvzoo d89d0dd7e1ba7a79aea715fcfea34ee9c0525b746a5da6d9825f4ab840c7e736   400000     data scientist          1.0
#                                           bzzcgklr 180 aa40d55a3029e678cab7df88a07d7648611050fc10a066e2de8afec3f9639fab   600000     data scientist          1.0
#                                       c ldgz kuknawslf 149cce98a8d0a8b4aab5f63dd2587aadfb16600a5817e1bc0517b3111c90d596  1000000     data scientist          1.0
#                                              c4sufstew ab95d39d7b08da8d0db63a5d0a69a02ea9ae37ce80b3efa775b22a3eed995b38  3000000     data scientist          1.0
#                           cdjiuw fdfwksukgnz fidnwsiuf db0ea39de4281fde007d82516ee2718b81a956dc7895bd6b11d7be55b1c9440b   850000     data scientist          1.0
#                           cdjiuw fdfwksukgnz findwsiuf 404ccb288d37e34d57cae507ef8422d12e977765c4d1ef7acde1b15dacf72239  2000000     data scientist          1.0
#                           cdjiuw fdfwksukgnz findwsiuf c7833d4034289c12b5176de85439b96d409a1203a5e815857a846c202debc200  1700000     data scientist          2.0
#                           cdjiuw fdfwksukgnz findwsiuf ed279ab67fa139674c67af727909a60946c802a1e7f480a54c9e57ad0d18635e  1600000     data scientist          3.0
#                           cdjiuw fdfwksukgnz findwsiuf db0ea39de4281fde007d82516ee2718b81a956dc7895bd6b11d7be55b1c9440b   850000     data scientist          4.0
#                                               cdlzu sw 7f609d45c0680c2d22954da9b391b558b62e2076df969daf28f856968695ab13  4100000     data scientist          1.0
#                                                 cdokuq b32c86cf889ae07e0fdc3c4f000d201545e899d7f30fe24310e6c7c005581397   900000     data scientist          1.0
#                                              cduuedhga f116378072b72b4dfec6b946ea0f61067179442ed194e3956f15da4f568f5fa0  1150000     data scientist         16.0
#                                              cduuedhga 4d4f0c30a994458a78825dcfb0c0a9d6a80f17c5cef3b7e3fc526195b9bd2259  1150000     data scientist         16.0
#                                              cduuedhga eb90f0a5114806187f2f6e47d7d0c01e1d16d8454c2bfaf4772e3f1188afaab4  1150000     data scientist         16.0
#                                              cduuedhga 617a49afbc5efc0f1692780d20fc566ba4ed4f1125491cce4e0dc3c71a91d77a  1100000     data scientist         17.0
#                                              cduuedhga a4fe56517dcfd745298fca7cfa2a17b2d8a95e3927ffe0fd4e27eda0fda90a78  1000000     data scientist         18.0
#                                              cduuedhga 538cd46045dcb73d1dbbe662177988e8b19895afce437adeccb2fb1aa64f86a7   900000     data scientist         19.0
#                                              cduuedhga ade21b16f1323291bdc12136046d99d4c875218f515b4edcf8c590cc7c66712f   880000     data scientist         20.0
#                                              cduuedhga 82587d83c2b70fad0d3eb495762da00836f33d398b51306467cdef0300966897   800000     data scientist         21.0
#                                              cduuedhga 60f6c165514307f610b94f002aa33a44390da3351036cb2db540a3daef94c2d7   800000     data scientist         21.0
#                                              cduuedhga f95330858da064e2d99e997e635955dd06b4862a2b04fbc03abac668a8b8b8e9   467000     data scientist         22.0
#                   cduuedhga sw fzosvslzf sucsk jvw nwc 289e0c061e25d8f26e9b30166bbb23d34a005fce17e6e82a0f262c211b3b0ba4  2300000     data scientist          1.0
#                                  cduuedhga sw fzovslzf 6ac37ec9f37a430b48c2b704e0b0f697729c5b62d7679b46c6325d853aa86bc5  1700000     data scientist          2.0
#                                  cduuedhga sw fzovslzf 69eabb89dd68da815d8183291a089085569e4f4d895f34d1db0adb162fa9862a  1689999     data scientist          3.0
#                                  cduuedhga sw fzovslzf c9cc574d1166f93dde6da1a2b54ef1c4c26e048edc324cf7174b7f08a2ed35e1  1320000     data scientist          4.0
#                                  cduuedhga sw fzovslzf 8d1a0d80d57f736f87c4a3340aa40752effcb7a4bac844941f78aeae609bc871  1300000     data scientist          5.0
#                                  cduuedhga sw fzovslzf c6fcb0ce5651aa444e346f15668208622b5de19c0faea9a4103e89706ed979f8  1000000     data scientist          7.0
#                                         cebn sufdokulz abce6b28078f352dcb43c50e0aa0fd52bfd7a364b4554586333dc8c0ce9fb3c6  2270000     data scientist          1.0
#                                                ceku ks 551d50218585f812eaaa5c49fb2066b140ce0fb712c6f2873d5093777bec8752   650000     data scientist          1.0
#                                               cesihslf 154e4bde6e0e3edab32723812d057c1cd17b076aead1e9484a787cc14684adec  1360000     data scientist          1.0
#                           cesihslf kuknawslf findwsiuf 0a7369b4735b50b6a07c71d7af01f5f18cfc5c9cc75355a3058944500ac241ac   530000     data scientist          1.0
#                                    cfh fekozc fzovslzf 0aeb61d51ae47eb2ab7558b8a48430d0e00ecc64d01080ed5c5319016b5c733b  2050000     data scientist          1.0
#                      cfj gnklroilr suvzfwhzuw hkuktzof 159c556beb6342003da1f100404f17602205d5777dadc24b939fad3088fd25bd  1250000     data scientist          1.0
#                        cfj suvzfwhzuw hkuktzof jvw nwc 78c2572d13b3474298fb9f7b5d310e7e047c09b134477a58bf8fe8f68b86b6be  1800000     data scientist          1.0
#                                       cg yzuwi fafwzhf ff446e4f9db831b5355fe50fad2b65e68d8116263d336178805bd97113dbe35d  1300000     data scientist          1.0
#                                               cgf gkur 3e20bbf5b1be5828b79202d386ff25e3c51314be1d60ddf5e687759875904376  8840000     data scientist          3.0
#                                               cgf gkur 13ed1c77a6961a9683ad363845c62186d052dc0d1f48bc146c1b6843553ac13e  2100000     data scientist         16.0
#                                               cgf gkur 0177202b15c66938ea8a061468928e036a7af0d0c1e8823eb163287d1f58fc56  2100000     data scientist         16.0
#                                               cgf gkur fdca92d09d4bb96383be5cd8438d83578e6fa7d09cbee6df99ce7a75862e1b0c  2000000     data scientist         18.0
#                                               cgf gkur 5f6be9983cfa8761bf9b4c70fe1dc4e1bae52c6ef46ff840fc84a4ba8cb41e07  1800000     data scientist         20.0
#                                               cgf gkur dbb25f857c0781d901198ed0ab9653fead5d18ac992d8cd318ef30d429e84dc3  1700000     data scientist         22.0
#                                               cgf gkur bcb4966ecc8041795ce97aa258e5cc10473914c13c8725891574cb74fdb4b671  1300000     data scientist         39.0
#                                    chs bsukulz jvw nwc 312427e90421d0fa2ad12b47b33cac872026635e5340e6ef9a50a672d173f295  1550000     data scientist          1.0
#                                    chs bsukulz jvw nwc 3aef83f2dddebbd9ffadfe2e42ad783a04b2607a55ebc1f1d5170288abb5c578  1500000     data scientist          2.0
#                                chs suuivkwsiuf jvw nwc d77ccb2a25e1d969b112d0da05dc9913ba93d031c2d307ed5b318f10c5d26f07  1900000     data scientist          1.0
#                                               cidgwudw 13f52c9815188b64c43bb09524fc1ce9d89957f253bf71b605864cfe58d44f79  1400000     data scientist          5.0
#     cilfkjj  liufdnw k fjzlsknsfw cilwio su 30 hsudwzf c0920cbc78839b4885bcedc6d6504fa8f5926dc4c8b22e3102e19798a5870848  1680000     data scientist          8.0
#     cilfkjj  liufdnw k fjzlsknsfw cilwio su 30 hsudwzf c0920cbc78839b4885bcedc6d6504fa8f5926dc4c8b22e3102e19798a5870848   850000     data scientist         14.0
#                                                cinlzok 6c1aec64f10a97705984d52dda909f853f1341caf0628051359ce5368e9d486e  1500000     data scientist          2.0
#                                                  ciqzz f5a54c15e6fb33c6d4b8f1f1f0d1178179fa59a3838b693c22184cfe49af4e3d  1900000     data scientist          1.0
#                                                 ciyjzo 49296e7780e009a02fe8d753af2845d0f1eba579ab3b4fa73abe685e22c58dc4  1400000     data scientist          2.0
#                                       ckffkdnw fafwhzf e62c7f993d40b47d3618d7e59397ce4cd9218f1556e8313762cc4eea92613297   900000     data scientist         35.0
#                                       ckffkdnw fafwhzf 333e1a6a3fb8dc4b7e332fb182512ce9f194db21b560ee3f6bff220de271c4ca   800000     data scientist         42.0
#                        ckhku ukwsiukn ezknwe sufdokulz 13af8056a1cdaab1c8ebd1be1c1ca3c93f6457c1a09ee33a1974f43bd931971b  1600000     data scientist          1.0
#                     ckjjnitsy fibwmkoz josvkwz nshswzc 078aa9964c1b858546d2cf3c5bba22c78bdfd0cb2f8bbf050dd88d2bffdd91bb   250000     data scientist          1.0
#                                              cksnaeduw 217d8c0f8ae0238c1f66e07331da040133126062bac724bffb4db065dbc604ab  1800000     data scientist         14.0
#                                              cksnaeduw e49db085dec28a3eae82f53c40ab3bb81951de9b301eaad8aa36dc15cfcb3fdc  1750000     data scientist         15.0
#                                              cksnaeduw 04f3f249a7ad0da78b1d3b66644c604dc1a74cad2dd12a165b189a90767a7f68  1680000     data scientist         16.0
#                                              cksnaeduw 4c89dd355407f76e9d8864885ffe89825de0535af6d7253c62cb57285ebd4fc6  1300000     data scientist         21.0
#                                             cksnausupk 5bfd76a911f24e1c0a3a087a7031419eb9def9e81bc6796d3dcdf3402f7e9ac5   700000     data scientist          5.0
#                                            ckufrz gkur 4d0ec6802e675da48bba5d95bcd6ce5aeaea2531684bf964115f61ef9b7559c7  1870000     data scientist          2.0
#                                          ckufrz gkursw 2abec45e6abbc53405b60de4f73224a33440f2de0d664998c23a92b0f6b09a80  1410000     data scientist          1.0
#                                              ckufrz sw e434ec8fa8038adcccfddcbbd83f7507a0c7f4ee75c76422f800e8eacd40bf35  1780000     data scientist          6.0
#                         ckufrz sw kuc fdjjiow fzovslzf e434ec8fa8038adcccfddcbbd83f7507a0c7f4ee75c76422f800e8eacd40bf35   580000     data scientist          2.0
#                                                 ckwisu 38f9fb137d92285754fd5e0f03dcc44223d2439fd5fe9283d0b6b4a087929c40   900000     data scientist          2.0
#                                             ckwk bklwq a066176dfd9ce77379a5b93170eee88506325843c930c9e5fc9096c3bcfcfbce   700000     data scientist          1.0
#                                         ckwk esvz nkgf 40b87d47f4e3146804ca1cb662e6bb04c1e5ff1e3bb6adea5d85fb2ef911391f   380000     data scientist          1.0
#                                      ckwk flszulz cipi 0feca19d26e2919e14f24bf6fc2c54f13c60682529b2bf88e37e8d07c3a89d3c  1009000     data scientist          1.0
# ckwk flszulz kuc ks toidj jesnsjf ezknwelkoz gkutknioz 992fbce8ecdda9113005ce84586fb43e2439994867de80009b2e31e9976751c4  4400000     data scientist          1.0
#                                ckwk flszulz liufdnwkuw def15e465578ad0ab3ab77537675841ddd38365082e7cf66ba142e17a7758b01   800000     data scientist          1.0
#                        ckwk flszulz woksuzz kw zcmsfio 01e291d69add1b6340ff19d8f4cb396ffb2a7a58c5b82b3a996161b5f1d6a31a   900000     data scientist          1.0
#                                         ckwk fzhkuwslf c91f3e7888b5f7f0ef6a750bc0825ee837fb86610f512951a136f2baace6ff3a   400000     data scientist          3.0
#                                      ckwk lioz fafwzhf 7e344c57465d420cc31319944380f7ece5af4481538fc28f36018242b2b3b2ae   740000     data scientist          1.0
#                                            ckwkbiducoa 04d3e4551f6b8ce9a4e981254c1ba2e77571fb3cdf1526fb31bdfb2cb3681e6a  1850000     data scientist          1.0
#                             ckwkhkwslf tnigkn fzovslzf d2b78d4f02a48d7be48dca1b37167a861c744140f08d2049ae05526f4928da9b  1480000     data scientist          1.0
#                     ckwkhkwslf tnigkn fzovslzf nshswzc 3632832f2b9bfa7776bbfb4b5cadf24f452c9ab77c84470838330fc79f537ee5   330000     data scientist         14.0
#                                ckwkhs higsnz findwsiuf 836a1a675478708e41d69937b939bb2ea38bb6dff55ad6cfe6b82a6dd45ccf9f  4300000     data scientist          1.0
#                                ckwkhswzf sucsk jvw nwc 3fdb856ef1f79cdb3e4c9f9a09a1917e79186a9c84207153c30927e602d7adef   350000     data scientist          1.0
#                   ckwkhzwslk findwsiuf josvkwz nshswzc a36831800a673718534fec5173d544e636eb6dff5a22e46aa9db5da8f23b0ff8   800000     data scientist         13.0
#                   ckwkhzwslk findwsiuf josvkwz nshswzc 827309eea011e3c31ad96cf7a337de303118e95b4cc7ed4cfe072f1c6a3b11e2   650000     data scientist         17.0
#                   ckwkhzwslk findwsiuf josvkwz nshswzc 25ae2297281b28be4b8038a5529bab37b95e811eed7d67a9bcea55766b7d9308   420000     data scientist         19.0
#                                      ckwkmzkvz jvw nwc 5f87a7a284ca4627068ad281a774fdab67abf886191ba985c9fe39f9f2cc8800  3000000     data scientist          1.0
#                                      ckwkmzkvz jvw nwc 4284c6d3434d477fbf778adfabd14a3cf7f558e14ae7afc24de9e94ab6b2c635  1450000     data scientist          2.0
#                                      ckwkmzkvz jvw nwc b4c7b46ad5b4502b0a57964442e9666e037d3f8c26975e6ee0c7d0be03a7fda2   360000     data scientist          8.0
#                                             ckwknslsdf bae9efcd4ab613df40ae00d61eef3cefcfcbcc6f7b11cc7799ff185888b943f2   750000     data scientist          1.0
#                              ckwko lkulzo tzuzwslf nwc 1ff2fc89c052605b6e99a4869c3cd14fba5002fc66ac4481bbf35d55a9ddb326   600000     data scientist          1.0
#                          ckwkvkn kuknawslf liojiokwsiu f35dfeb44297fa724972a0be0ad8797f7f327d9559c9c62bb40971e509774c6e   800000     data scientist          1.0
#                          ckwkvkn kuknawslf liojiokwsiu 0efb73a2d8dbff4629df8a514d1309a7585a16f954219f75cf3f26b220cf7cb4   450000     data scientist          2.0
#                          ckwkvkn kuknawslf liojiokwsiu 0efb73a2d8dbff4629df8a514d1309a7585a16f954219f75cf3f26b220cf7cb4   450000     data scientist          2.0
#                           ckwkxkjjf wzleuinita jvw nwc 77736bc50ac1bec493fe6fec8a8b9ad56fcfca46bcc032ae373298d651f44244  1019999     data scientist          1.0
#                                               clg gkur 714c98da527c096d717e305eab027cbe0af3d85320c5310766c10566cbeb1bd2  1310000     data scientist          1.0
#                                                   cnjn dd1db62226070bec7f9692c5707967b315fc30b96d67f7c9311b04f079aa9592  2000000     data scientist          1.0
#                                             coci cznes f8f171c2b313bf742f48a7b0d9d5d79ec9332def6253aa84b95d859ff726a891   520000     data scientist          2.0
#                                         coci gkutknioz 64f1f38fd5e2c7331028b52655060719d60fd59178748ec0b9df644e7f58426d  1400000     data scientist          2.0
# ...
#                                               cznn zhl cf3bb711387e1ba3e4559cdc8af123bfe9f52b08f8237fe5c96f7feb07ec8feb  1500000     data scientist         69.0
#                                               cznn zhl ecb83e94e6174599bf26dab962bb664de08434e32de2601148223f4ed685187d  1200000     data scientist         88.0
#                                               cznn zhl a51af3126efdbbcb95e055e45c0453ec0f539a926522888a8aaaaeb4a6dcda1c   900000     data scientist        102.0
#                               cznsvzoksu wzleuninitszf d29762b12c69fc4079e5fe26a560164c0e1f182e6e534a1dfcbb6efbcc469866   400000     data scientist          1.0
#                                        cznwk kso nsuzf d51cb025f100b341fdc3a624ee38f449d298ff7cbd503c2a761ea414d4f59b4f   700000     data scientist          4.0
#                               cznwk wzleuinita jvw nwc 1a2628ebab1cd9fb22a75f44e79dc233ff65b00cc48090e733e235bb06827338  1500000     data scientist          1.0
#                                                 cznwky 4bdc644cf75550c8c1b0278f38468698808c8e4a6bba345cfd062444029ef083  1000000     data scientist          1.0
#                                                 czosfr 8273c59c925938a706b03e9dd5d9f555308a32f201706b1d209cb121e3d4a4e7   430000     data scientist          1.0
#                                   czukvz sucsk jvw nwc a3c356fd2fc21cc3cc0718a66fe08f14b61d863a50e13815c7e01202557eddf3   700000     data scientist          1.0
#                               czvpsvk fibwmkoz jvw nwc 1918d1fa8eb6f98695fe433aac03bdb9bbef0b94ba4bf47d0448856bbe59ec68  1800000     data scientist          1.0
#                          czvznijhzuw gkur ib fsutkjioz 770d7d07ff5fc4eb28943dec56a39321b71a55276cf880612c531b0feb6f54a1  1350000     data scientist          2.0
#                                             czywzoskwa 553b895c4ea832b89738d2882667efa766083761d7bbeff684db6559c6e7d7b7   750000     data scientist          1.0
#                                             czzjgoksuq e29953e92ba46d3c7b036f5ae33174bfcbcea2cd5beeb4f3858eb7f5387eefa4   500000     data scientist          1.0
#                                          czzjnitslwzle c2450192c2913bbda6bd28db05addb2618f8ac68581a8a7554c92130d19ef156  1050000     data scientist          2.0
#                                          czzjnitslwzle c2450192c2913bbda6bd28db05addb2618f8ac68581a8a7554c92130d19ef156   680000     data scientist          3.0
#                                                 czzjsx 95dbfd2a99ffa35e647376b5c0bb08f6d3f7da9a02aae5dfbf19d1067861fc9d   800000     data scientist          1.0
#                                             czzjzctzks 05850d958e1270fa02174778c3d139014a27e2b8491d6069127a5965c593f0ba  1984000     data scientist          1.0
#                                          d toi lkjswkn b14f14c3722d61a483e8c88f25874bbd2a84705ecfafb343e0960606f60ed8cc   710000     data scientist          1.0
#                                               dckkulih 2c110d62128b9467adfa6ddb88aacdf57f840784f518ee401a4b0674a93e3f71  1500000     data scientist         10.0
#                                                dcklswa 6a9452844b94e290554ea28a9151b30648725cab6b93ae51685f2ba1d7f9f527  1000000     data scientist          7.0
#                                             dfw tnigkn 11dda8526fa6965bd3e76df6f601544ab4b428ff646c945634e9e3e9b67a0c94  1500000     data scientist         19.0
#                                             dfw tnigkn 7289cd4afa7edeef7c3ff913db1ea757dd33d6acf3ab7cad1cb3df927b4099c1  1400000     data scientist         21.0
#                                             dfw tnigkn b8afa498821a5b8d07beb0e7342712917f13964b28186a57de074b386956ce4c  1180000     data scientist         29.0
#                                             dfw tnigkn f85ee0d76fc0d1faa9028e03279064a83b6a50e1cfb673e0550c14b79f0db724  1100000     data scientist         31.0
#                                             dfw tnigkn 13e4a20c3f823df952d9e7689eb24879af758632aff588326ffeaefc8eab83cb   810000     data scientist         49.0
#                                             dfw tnigkn 24af3b57faa19a23c027db68b1466d3fde257787c4943bc5aab3d8081318e80f   660000     data scientist         60.0
#                                             dfw tnigkn 19fae9fd1bc7d331a255f80f0839ee4accd273a801d608b2ad313329e6c46237   650000     data scientist         61.0
#                                             dfw tnigkn 74242b10fd6f611095cecb510cfcf4e84c0ec87926562490944ecba4f53b5657   650000     data scientist         61.0
#                                             dfw tnigkn 0f029bbc33f269470fb4ba03968d9c06e59c4a92aead9a543a02196ee4f9027e   600000     data scientist         63.0
#                                            dfw tnigknf 6a7daffa8075d0121c60c9d67fb1692b15a7cd067811c511d0628ee23ba0b355   450000     data scientist          1.0
#                                                    dgf e9bf51b849ccb739780f05e3386557110b2262ffaba11b41952ecc0dcb221781  2400000     data scientist         10.0
#                                                    dgf 7e8fc0df2e286daca3ab44a238da8911683c93d10e8be6105036a498bc50dc33  2300000     data scientist         11.0
#                                                    dgf 19e17526322dfe5ad6d0f1a2044f32a7dae543d9c4fb5769848e89c1232275cb  1900000     data scientist         17.0
#                                                    dgf 5ca3c6a55ac4e0a8c9ac5d55e8809c9e71dd161782044e725ae13305ff5a0af8  1800000     data scientist         18.0
#                                                    dgf c7dadc20f1145c3d0a1997f19a14bc92da744cddc41ff578aa60995a439bfc7f  1200000     data scientist         29.0
#                                                    dgf f334d402e1e49a297b00fb3f466b64e746f320486b6001922805a86b2a794cff  1150000     data scientist         31.0
#                                                   dgzo ac33c19bb52274fd8387e253ad13cd3cf456517f163cf1d205cf4bde389768ab  1500000     data scientist         54.0
#                                                 djmior 45a993432b5f07b063d0b7bbcace916121b956e4cfe85ba099e69b3c18d41d1b  1200000     data scientist          4.0
#                                                 djmior ecca3acd98f650ac301c15cd999d0b79d07ae2acc34aded5a55575e2d79417f9   500000     data scientist         11.0
#                                              djmiorlih 12719ddd9fbedaee49fc021a6c9f268df9142ed13b24eca3b264967bcb4bf10b  1400000     data scientist          1.0
#                                              djtokclih 067010206ab3652ae389863f79f614a1634a7d3c00da02f2ba77e040677f61b5  1200000     data scientist         25.0
#                                                    dln e0ac13ab7084c366034ba0e2dbef4f608380ee3dfb7e2bd1e362e80b917479e8  2875000     data scientist          1.0
#                             dof wzleuinitszf findwsiuf 6514f814004627ec4048675b2fa1305b73b05c07b56d09f684a380d92fdb04d3   830000     data scientist          1.0
#             dogkuswa hdnwsfin josvkwz nshswzc hacscssu e34b4b1bb684818436b8def1997d35767a800b27d645ce66f115ec503f491eb9  1900000     data scientist          1.0
#                                                 dsjkwe 84dd6adcbb60eceaebb0560d9d39af84b24ba7948cf499e36140ebf72be360dc  3170000     data scientist          8.0
#                                                 dsjkwe ed57ba3de1fc74b60a88aaa11726cc1fb8d169bdb0cdb6c3846852a810500b3d  2970000     data scientist         10.0
#                                                   dtkh 17aa6f7254a28617b2af27e204620aab874a9e8d1d4c87ac6c681146fb4f7830   270000     data scientist         12.0
#                                 duczo tokcdkwz fwdczuw 478986b3f5d671892c0b50dcbe8cf7c204645eda4154f33da68839e7de51b57f   830000     data scientist          1.0
#                                              dugyc sul f386f6cffdfcb66c0b914cf3c4d57887e9a3681a10bbc720d78fad73c85afe77  3600000     data scientist          4.0
#                                              dugyc sul 6c91a501207b2ff3711ca7545916a530004822e024d554c88431646c09185d62  2670000     data scientist          6.0
#                                              dugyc sul 5394bc35a9e02fd53c8b7b114c1f92cf514d1c2d8dbf0c1ccb494812f7d18954  1800000     data scientist          7.0
#                                dunshsw siw jvw nshswzc c3d72c41626f94bb59b6488efde8dc6144a831e9caceff19b053c8957ed54182   600000     data scientist          1.0
#                                                  dusba 3fd9b10bac53c5c3bc548632e48054c0b8fda4c40f62f4941e439efc2b77530f   880000     data scientist          5.0
#                                                dusbauc ab2f5cdd9a8fabe1584caeca1a075e3ced28f075eb269b2e4058ae501d9873f7   480000     data scientist          1.0
#                                                 dusfaf a57a20dadddd8f3aafd84a5bd66910be86097ff9acf732e8cf88561c595595a3   700000     data scientist         22.0
#                                                 dusfaf 16f3c5696ccbdcbc2d6a219b4256fa1c185f0ef43b12b66174f9cd5de8139fd2   600000     data scientist         31.0
#                       dushius tnigkn gdfsuzff fzovslzf 3227522d1f0961afb6e05429a079d5621b3cee1961616e019d0cab97292b1af1  1839999     data scientist          1.0
#                                               dusjeioz d5ae79d272a05a050494117d8a04612644026588c10f870cba251064e421ac31   520000     data scientist          1.0
#                                               dusnzvzo dd18e03527be2ab1086c24f07b381169fef5f4ace69f6fa2d0eab10967c33593  1019999     data scientist          9.0
#                                               dusvofzf e60368f9ab6084375fad2c7bf280415f85be3074ed8ab1ef9fc614489d9029ba   400000     data scientist          1.0
#                    dusvzofswa ib hkffkledfzwwf khezofw 1d4e5050b7d9b30041b8e173ba0428a61efe7529825f526e3a6031250bcfe36f  3000000     data scientist          1.0
#                                       duswak kt gzonsu cfc0872a8697cb007bbf5cb32801ff538e977d7641ad8f543f44ec9dc9e3d1f2  4000000     data scientist          1.0
#                              duswzc ezknwe toidj ijwdh 3638459a756af31d2126f42419a1ebedc31d226f2e288a454fc05194821a8ed6  2180000     data scientist          3.0
#                               duswzc findwsiuf lihjkua a0c2c7bf1f7790bf72332401da5cb55a28ab046723d5043fbe09322740d529b5   400000     data scientist          2.0
#                                    duswzc wzleuinitszf 4f062d327bcfe0cbba484d629a51d3236db2f8b385139cfee691313ace8297ca  1600000     data scientist          2.0
#                               duswzc wzleuinitszf lioj 465e6c2f5c48630e140c181b0eabe81880920008333f5ecf3018eed2ecd88165  2600000     data scientist          1.0
#                                     duswzcezknwe toidj 1953f81061c14ed86f8e6e734e970730272a690128d43893a11bece487729553   869999     data scientist        113.0
#                                     duswzcezknwe toidj 0bf511351e10404c10ee74c285fca992d2e9da873424dac7d99d17568c8d7e24   850000     data scientist        114.0
#                                     duswzcezknwe toidj 7ae3e376a6016e29a14b5c33f6e5b5d6868a6d2e59e6ce21980323a99106be92   830000     data scientist        115.0
#                                     duswzcezknwe toidj 2743f00cfb83678ad6ce819a44668628afc59bf77db14a03c2ed9fefcb29d505   800000     data scientist        116.0
#                                     duswzcezknwe toidj 23271ffa158dbedff7c376e0658b64564b600f956902519e40d3037ecbe796c5   800000     data scientist        116.0
#                                     duswzcezknwe toidj fcb39f618acc7cb02cd1d8c489ba538fd394b1c81a567f332b8c7898f7c4f67c   760000     data scientist        117.0
#                                     duswzcezknwe toidj ecff083d5035af7ebaa825040013dc65575cddffb7783eac71c3306b0fdb902d   700000     data scientist        120.0
#                                     duswzcezknwe toidj 753d8c2d1962a5a9799061941afc5ae8a1e65987fa065b3a3a65292b9f9e2509   670000     data scientist        123.0
#                                     duswzcezknwe toidj 307731d14748cd1c7c2c51277c19000aae2376dba8c456bf94cbdeb9e161025d   670000     data scientist        123.0
#                                     duswzcezknwe toidj 8b4b0ca5cd0749001194676fff530633bf97bb6b271ed52ac7ecdc0a2dc2924e   480000     data scientist        138.0
#                                         duwoicczu nkgf 33379e00fc7823b64f621ce7314b1f3561d332fc6b798fc72e1efddc1a8a6c9b   900000     data scientist          1.0
#                                             duzhjinazc 7e4ec8b7422c753131d88f98f34f10bfd63fced12bb1888a031ea39f92bf0add  1600000     data scientist          2.0
#                                             duzhjinazc 62a0418bf0cc7c642b591d4c65dbb0eda035a500c195a9458176ccaaa935a529   850000     data scientist          7.0
#                                             duzhjniazc dd9e496e4f5a8813d03bb4536f68e383ab2356b26c34b975108bb833902c8b39  1200000     data scientist          4.0
#                                             duzhjniazc 6fc6652d9f54e79a6e3ebf4c23e76ab292585d84c536f5a3ff4f8b53c1822755   980000     data scientist          6.0
#                                        dwijdf sufstewf 17449e9d4144624a8396fa23b08fd5e7a86c487837978880290c944919108836  1739999     data scientist          1.0
#                                          dwijsk tnigkn 108d6441d6cbfa057c4ea512d0ee90c1f625abf144ee384b15454c881fde6db3  1200000     data scientist          1.0
#                                          dwijsk tnigkn 387afecbe20e0aa3e5ef392279b44396584255f61788a78ee2682d153135965e  1000000     data scientist          2.0
#                                          dwijsk tnigkn 387afecbe20e0aa3e5ef392279b44396584255f61788a78ee2682d153135965e  1000000     data scientist          2.0
#                                          dwijsk tnigkn d776fed6ff2192ac31e4a281a4e74fd8e368484edf7b67e2e2b75083f4ccdf86  1000000     data scientist          2.0
#                  dwl eaczokgkc ozfzkole  czfstu lzuwzo 0df601104b659b3650e64c69297e3a58b712b79f17ebd7e8ef8c33491e8b84fe  1700000     data scientist          1.0
#                        e4wknzuw loh iu fswz gkol sucsk ac782b650bbba45a94de028036b60e4e167a5d7cc1df0a89369ff4effd0961de   650000     data scientist          1.0
#                                          eaducks higsf b13cbe06657541e7e48832a1039ce817f92aef86bcc8619c23448083298c7cb0  1200000     data scientist          4.0
#                                 eaducks kdwizvzo sucsk b34eab8d0bd7ceb9b90bb7a319baf15cd9cb739ab69c5600485e28a69e68ac0e  1700000     data scientist          1.0
#                                 eaducks kdwizvzo sucsk b34eab8d0bd7ceb9b90bb7a319baf15cd9cb739ab69c5600485e28a69e68ac0e  1500000     data scientist          2.0
#                                      eafwzo aknz toidj 2e0f8b9d9a19967597a1326edb09b4c269eabe22b558f4174ea310fb7349bfd0   630000     data scientist          1.0
#                                             eajzofiusy c52a207d22cdc74ad47e06dd8e90a75175d1c5c499ed64126a5d8ca89475564e  4000000     data scientist          1.0
#                                         eajzofiusy sul e89a614280e7aefc123acb8bcd7fd0ca7f124b387e36c1204c0e756698930b03  2000000     data scientist          1.0
#                                                   ebln 1fb717918b9171942486a54bec48c9659398275708a12025910930aaa1ca9b06  1500000     data scientist          1.0
#                                 ecbl czvznijzof hdhgks 2785a256d55e6412c484ae244cebd43a9b45ce9d052013a1391ecf6a59ab62a1   910000     data scientist          1.0
#                                              ecbl gkur 719fa3664c2059719b40ac1f3663679f5855fe91bfa45ffed5db470dfabad3fd  1210000     data scientist          5.0
#                                              ecbl gkur 8f8b93865190b9597e9f8cb8f42994fd1df327736dce35c5762e4b1872a5fe0e  1200000     data scientist          6.0
#                                              ecbl gkur d1ce5c5989abc06d0d19649a6650568c0b3c8e76ef9059712234da108ee9ce10   919999     data scientist         11.0

# %% [markdown]
# ##Conclusion 5: Top 10 companies (based on their CTC)

# %%
df_mrg_ctc_sorted.head()
# Out:
#                           company_hash  \
# 134097                            0000
# 34982                       01 fauzota
# 47362                       01 fauzota
# 92292   05gu bsuezknwe josvkwz nshswzc
# 64530                           1 azko
#
#                                                email_hash  orgyear      ctc  \
# 134097  b3f3bb98cbca4b1ce5dfd5abb4e500ce6f6b66288a5202...   2017.0   300000
# 34982   e1e15fada844f35fcc33927343d0c80f55526b87c40eee...   2011.0   830000
# 47362   819789ff4068fd5c8facf8a5074cdd2e1ff989c95ae02c...   2016.0   270000
# 92292   4702229ffb6968c87b16fc57e730769e554184e322e111...   2019.0  1100000
# 64530   034ae72dd3b77497e96173751f8805d5314bc2363e30c2...   2018.0  1700000
#
#         ctc_updated_year  job_position_clean  experience  offer_count  count  \
# 134097            2020.0              others         3.0          1.0      1
# 34982             2019.0  frontend developer         8.0          1.0      1
# 47362             2019.0    android engineer         3.0          1.0      1
# 92292             2021.0    backend engineer         2.0          1.0      1
# 64530             2019.0    backend engineer         1.0          1.0      2
#
#              mean  ...  cp_jb_median  cp_jb_min  cp_jb_max  ctc_cp_jb_status  \
# 134097   300000.0  ...      300000.0     300000     300000                 2
# 34982    830000.0  ...      830000.0     830000     830000                 2
# 47362    270000.0  ...      270000.0     270000     270000                 2
# 92292   1100000.0  ...     1100000.0    1100000    1100000                 2
# 64530   1180000.0  ...     1180000.0     660000    1700000                 3
#
#           cp_mean  cp_median   cp_min   cp_max  ctc_cp_status  ctc_rank_cp
# 134097   300000.0   300000.0   300000   300000              2          1.0
# 34982    550000.0   550000.0   270000   830000              3          1.0
# 47362    550000.0   550000.0   270000   830000              1          2.0
# 92292   1100000.0  1100000.0  1100000  1100000              2          1.0
# 64530   1180000.0  1180000.0   660000  1700000              3          1.0
#
# [5 rows x 26 columns]

# %%
tmp = df_mrg_ctc_sorted.sort_values('ctc',ascending=False)
print(f"Top 10 companies Based on their CTC")
tmp.head(10)[['company_hash','ctc']]
# Out:
# Top 10 companies Based on their CTC
#                                              company_hash       ctc
# 130317  joicdlw liufdnwkuw wkwk lnsx hktslgoslrf hdnws...  13000000
# 74223                                          giirsutlih  13000000
# 77827                                          giirsutlih  13000000
# 13130                                    khzoslku zyjozff  13000000
# 33810                                              khcilf  13000000
# 100940                                             ioklnz  13000000
# 66551                                                vsfk  13000000
# 59677                                         wosjkcvsfio  13000000
# 70577                                           eznjfesbw  13000000
# 104250                              ezykmkoz wzleuinitszf  13000000

# %% [markdown]
# ##Unspervised Learning - Clustering
# Checking clustering tendency

# %%
df_mrg_ctc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139095 entries, 0 to 139094
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   company_hash        139095 non-null  object
#  1   email_hash          139095 non-null  object
#  2   orgyear             139095 non-null  float64
#  3   ctc                 139095 non-null  int64
#  4   ctc_updated_year    139095 non-null  float64
#  5   job_position_clean  139095 non-null  object
#  6   experience          139095 non-null  float64
#  7   offer_count         139095 non-null  float64
#  8   count               139095 non-null  int64
#  9   mean                139095 non-null  float64
#  10  median              139095 non-null  float64
#  11  min                 139095 non-null  int64
#  12  max                 139095 non-null  int64
#  13  ctc_above_avg       139095 non-null  int64
#  14  ctc_status          139095 non-null  int64
#  15  cp_jb_mean          139095 non-null  float64
#  16  cp_jb_median        139095 non-null  float64
#  17  cp_jb_min           139095 non-null  int64
#  18  cp_jb_max           139095 non-null  int64
#  19  ctc_cp_jb_status    139095 non-null  int64
#  20  cp_mean             139095 non-null  float64
#  21  cp_median           139095 non-null  float64
#  22  cp_min              139095 non-null  int64
#  23  cp_max              139095 non-null  int64
#  24  ctc_cp_status       139095 non-null  int64
#  25  ctc_rank_cp         139095 non-null  float64
# dtypes: float64(11), int64(12), object(3)
# memory usage: 27.6+ MB

# %%
#Checking clustering tendency
#Preprocessing Data
df_mrg_ctc_shrink = df_mrg_ctc[['company_hash','job_position_clean','experience','ctc']].copy()

# %%
df_mrg_ctc_shrink
# Out:
#                      company_hash  job_position_clean  experience      ctc
# 0                  czniswwz sucsk              others         4.0  1100000
# 1       oznskulz subilihh nshswzc  fullstack devloper         1.0   449999
# 2                   faulwklwsl ks    backend engineer         5.0  2000000
# 3                       wirijzcsk    backend engineer         2.0   700000
# 4                      osbw toidj  fullstack devloper         2.0  1400000
# ...                           ...                 ...         ...      ...
# 139090          lft suwzoukwsiukn  fullstack devloper         5.0  1500000
# 139091                    subifaf  fullstack devloper         2.0  1200000
# 139092          lihjuivk liuwoklw      data scientist         6.0  1000000
# 139093                  cduuedhga      data scientist         2.0  1100000
# 139094      bnzywokcz fafwzhf nhw  frontend developer         4.0  1100000
#
# [139095 rows x 4 columns]

# %%
df_mrg_ctc_shrink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139095 entries, 0 to 139094
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   company_hash        139095 non-null  object
#  1   job_position_clean  139095 non-null  object
#  2   experience          139095 non-null  float64
#  3   ctc                 139095 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

categorical = ['company_hash', 'job_position_clean']
numeric = ['experience','ctc']

preprocess = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical),
        ('num', StandardScaler(), numeric)
    ]
)

X_processed = preprocess.fit_transform(df_mrg_ctc_shrink[categorical + numeric])

# %%
print(X_processed)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 556380 stored elements and shape (139095, 30468)>
#   Coords	Values
#   (0, 2329)	1.0
#   (0, 30237)	1.0
#   (0, 30466)	-0.2261484750716477
#   (0, 30467)	-0.23676199012889834
#   (1, 19472)	1.0
#   (1, 30157)	1.0
#   (1, 30466)	-0.9931527130549248
#   (1, 30467)	-0.7493226800490187
#   (2, 3966)	1.0
#   (2, 30068)	1.0
#   (2, 30466)	0.029519604256111304
#   (2, 30467)	0.47293633483999914
#   (3, 26587)	1.0
#   (3, 30068)	1.0
#   (3, 30466)	-0.7374846337271658
#   (3, 30467)	-0.5521834678928528
#   (4, 19088)	1.0
#   (4, 30157)	1.0
#   (4, 30466)	-0.7374846337271658
#   (4, 30467)	-0.00019588180593252025
#   (5, 3333)	1.0
#   (5, 30157)	1.0
#   (5, 30466)	-0.7374846337271658
#   (5, 30467)	-0.5521834678928528
#   (6, 19778)	1.0
#   :	:
#   (139088, 30467)	-0.35504504429038125
#   (139089, 10898)	1.0
#   (139089, 30068)	1.0
#   (139089, 30466)	-1.2488207923826837
#   (139089, 30467)	-0.31561735956988696
#   (139090, 15262)	1.0
#   (139090, 30157)	1.0
#   (139090, 30466)	0.029519604256111304
#   (139090, 30467)	0.07865948763505609
#   (139091, 21786)	1.0
#   (139091, 30157)	1.0
#   (139091, 30466)	-0.7374846337271658
#   (139091, 30467)	-0.15790662068790973
#   (139092, 15527)	1.0
#   (139092, 30109)	1.0
#   (139092, 30466)	0.2851876835838703
#   (139092, 30467)	-0.31561735956988696
#   (139093, 1370)	1.0
#   (139093, 30109)	1.0
#   (139093, 30466)	-0.7374846337271658
#   (139093, 30467)	-0.23676199012889834
#   (139094, 850)	1.0
#   (139094, 30155)	1.0
#   (139094, 30466)	-0.2261484750716477
#   (139094, 30467)	-0.23676199012889834

# %% [markdown]
# What the printed output means (row, column) → value
# Example:
# (0, 2574)    1.0
# (0, 33325)   1.0
# (0, 33566)  -0.22614919607
# (0, 33567)  -0.10437870682
#
# Let’s decode this.
# Row 0
# These are the non-zero features for the 1st row of your input:
# 🔹 1.0 in one-hot columns
# (0, 2574) = 1.0
# (0, 33325) = 1.0
#
# This means:
#
# Column 2574 → one category is active (e.g., "company_hash = X")
# Column 33325 → another category is active (e.g., "job_position_clean = Y")
#
# One-hot encoding always produces exactly two 1's for two categorical columns (one for each).
#
# 🔹 Negative values in the last two columns
# (0, 33566) = -0.2261
# (0, 33567) = -0.1043
#
# These are scaled numeric values:
#
#
#
# Column indexOriginal featureAfter StandardScaler33566experience(value - μ₁)/σ₁33567ctc(value - μ₂)/σ₂
# Since values are below their mean, the z-score is negative.
#
# 🔍 Why 33568 columns?
# Because:
# #columns = (#unique company_hash categories)
#           + (#unique job_position_clean categories)
#           + 2 numeric columns
#
# Example:
#
#
# FeatureUnique categoriesColumns producedcompany_hash15,00015,000job_position_clean18,00018,000experiencenumeric1ctcnumeric1
# So roughly:
# 15000 + 18000 + 1 + 1 = 33,002  (close to your ~33,568)
#
# Large one‑hot expansions are very normal for hashed categorical fields.
#
# 🔍 Why sparse matrix has only ~588,400 non-zero elements?
# Because each row only has:
#
#
# Column typeCountcompany one-hot1job_position one-hot1scaled numeric2
# So per row: 4 non-zero values → 4 entries.
# Total rows = 147100
# Thus approx non-zero:
# 147100 × 4 = 588,400   ✔ exactly what you have
#
# This confirms everything is working correctly.
#
# 🔥 Intuition (C parallel)
# In dense representation, you’d need:
# 147100 * 33568 ≈ 4.9 billion floats
# ≈ 39 GB of RAM (float64)
#
# But you are storing only ~588k non-zero values → memory usage reduced by ~100x.
# CSR is exactly the optimized way you’d implement this in C.
#
# 🧠 Final Summary
# What your output means:
#
# Row = sample index
# Column = encoded feature index
# Value = 1.0 (for one-hot) OR scaled numeric value
# Sparse format because 99.9% of matrix is zeros
# Shape = (147100, 33568) → very normal for one-hot encoding large categorical features
# 588,400 non-zero elements = perfect (≈4 per row)

# %%
preprocess
# Out:
# ColumnTransformer(transformers=[('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['company_hash', 'job_position_clean']),
#                                 ('num', StandardScaler(),
#                                  ['experience', 'ctc'])])

# %%
X_processed
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 556380 stored elements and shape (139095, 30468)>

# %%
X_processed
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 556380 stored elements and shape (139095, 30468)>

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import random

def hopkins(X):
    X = np.array(X)
    n = len(X)
    m = int(0.1 * n)  # sample size

    nbrs = NearestNeighbors(n_neighbors=1).fit(X)

    # random points in same range
    rand_X = np.random.uniform(np.min(X, axis=0), np.max(X, axis=0), (m, X.shape[1]))
    u_dist, _ = nbrs.kneighbors(rand_X)

    # sample real points
    random_indices = random.sample(range(n), m)
    w_dist, _ = nbrs.kneighbors(X[random_indices])

    H = u_dist.sum() / (u_dist.sum() + w_dist.sum())
    return H

# %%
X_dense_sample = X_processed[np.random.choice(X_processed.shape[0], 1500, replace=False)].toarray()

# %%
h = hopkins(X_dense_sample)

# %%
print(h)
# Out:
# 0.9999999996447575

# %% [markdown]
# ## Conclusion 6 : Hopkins value 0.99999 indicates very strong clustering Tendency

# %%
# PCA Plot analysis
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# sample 3000 rows
idx = np.random.choice(X_processed.shape[0], 3000, replace=False)
X_sample = X_processed[idx].toarray()

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_sample)

plt.scatter(X_pca[:,0], X_pca[:,1], alpha=0.5)
plt.title("PCA Visualization of Feature Space")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# **1. The Plot Shows That Most Variance Is in PC1
# PC2 almost carries no variance**
#
#
# Almost all points lie near PC2 ≈ 0
# Only a handful are higher (outliers on PC2)
# PC1 spreads widely (from about –1 to +5)
#
# 👉 Interpretation
#
# PC1 is capturing almost all meaningful variation in your data.
# PC2 contributes very little (almost flat → collapsed to near-zero).
#
# This is typical when:
#
# Your dataset is heavily dominated by one-hot encoded categorical variables (company, role).
# One principal direction explains almost the entire structure.
# The second dimension doesn't help separate clusters.

# %%
# Elbow method

#Limiting sample size as colab is not able to handle larger data size
idx = np.random.choice(X_processed.shape[0], 3000, replace=False)
X_sample = X_processed[idx]

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertias = []
K_range = range(2, 16)  # try K = 2 to 15

for k in K_range:
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init='auto'  # or n_init=10 for older sklearn
    )
    kmeans.fit(X_sample)
    inertias.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(list(K_range), inertias, marker='o')
plt.xticks(list(K_range))
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia (within-cluster SSE)')
plt.title('Elbow Method for K-Means')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Conclusion 7 : Based on the Elbow method K = 3

# %%
##Conclusion 7 : Based on the Elbow method K = 3

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=100, random_state=42)
X_reduced = svd.fit_transform(X_processed)   # X_processed is sparse

# %%
X_reduced
# Out:
# array([[-3.60615751e-01, -2.18013193e-02,  1.36601404e-02, ...,
#          5.67229370e-04, -2.28648952e-03, -2.61097935e-03],
#        [-1.25850935e+00,  2.07472681e-01, -3.72209128e-02, ...,
#         -1.77319393e-03, -1.68136672e-04,  3.91043571e-03],
#        [ 3.56396283e-01,  4.56271439e-01,  9.40100870e-01, ...,
#          2.91859837e-04, -1.32687648e-03, -3.53817312e-03],
#        ...,
#        [-2.04908421e-02, -4.12330783e-01,  5.95418982e-02, ...,
#         -2.19232850e-04, -1.56535300e-03, -3.29001983e-04],
#        [-6.85805450e-01,  3.55272806e-01, -5.20309490e-02, ...,
#          6.22368003e-04, -1.75371720e-03, -8.72302155e-04],
#        [-3.32341603e-01, -2.54179610e-02,  1.02935931e-02, ...,
#          9.81399516e-04, -2.64069163e-03, -1.67027011e-03]])

# %%
# 2. Fit KMeans on full PCA data
kmeans_final = KMeans(n_clusters=3, random_state=42, n_init='auto')
cluster_labels = kmeans_final.fit_predict(X_reduced)

df_mrg_ctc_shrink['cluster'] = cluster_labels

# %%
df_mrg_ctc_shrink['cluster'].unique()
# Out:
# array([1, 2, 0], dtype=int32)

# %%
df_mrg_ctc_shrink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139095 entries, 0 to 139094
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   company_hash        139095 non-null  object
#  1   job_position_clean  139095 non-null  object
#  2   experience          139095 non-null  float64
#  3   ctc                 139095 non-null  int64
#  4   cluster             139095 non-null  int32
# dtypes: float64(1), int32(1), int64(1), object(2)
# memory usage: 4.8+ MB

# %%
cluster_summary = df_mrg_ctc_shrink.groupby('cluster').agg({
    'ctc': ['count', 'mean', 'min', 'max'],
    'experience': 'mean',
    'company_hash': lambda x: x.value_counts().index[0],
    'job_position_clean': lambda x: x.value_counts().index[0]
})

print(cluster_summary.to_string())
# Out:
#             ctc                                  experience               company_hash job_position_clean
#           count          mean      min       max       mean                   <lambda>           <lambda>
# cluster
# 0          7993  5.088158e+06  3000000  13000000   6.755911                     khkqiu   backend engineer
# 1        102668  9.835382e+05   200000   3500000   3.177991  wkwk liufdnwkula fzovslzf   backend engineer
# 2         28434  1.868186e+06   200000   5020000  10.520398                     ioklnz   backend engineer

# %% [markdown]
# ## Conclusion 8 :  Insights from Unsupervised Clustering
#
# **Cluster 0 — High CTC, Highly Specialized Talent**
# 📌 Size: 7,993 profiles (smallest cluster – top of the pyramid)
# 📌 Avg CTC: ₹50.8 L
# 📌 Max CTC: ₹1.3 Cr
# 📌 Avg Experience: 6.75 years (surprisingly low!)
# 📌 Dominant Role: Backend Engineer
# 🔍 Interpretation
# This is your high-value, niche salary cluster.
# IMPORTANT OBSERVATION:
# Despite having only ~6.75 years experience (mid-level),
# CTC is extremely high → 30–130 L.
# This indicates:
# 🔥 These are specialized senior engineers, niche startups, FAANG-like roles, or outlier high-paying companies.
# 🧠 Business Insight
# Salary inflation for niche high-performance engineering talent
# Competitive pressure from elite tech companies
# High salaries not proportional to experience → skill-based premium
# This cluster contains roles where pay is dictated by company tier, not just experience
#
#
#  **Cluster 1 — Entry‑Level / Early‑Career Talent (Majority Segment)**
# 📌 Size: 102,668 profiles (70% of entire dataset)
# 📌 Avg CTC: ₹9.8 L
# 📌 Experience: ~3.2 years
# 📌 Max CTC: ₹35 L
# 📌 Dominant Role: Backend Engineer
# 📌 Dominant Company Hash: wkwk…
# 🔍 Interpretation
# This is your mass market talent pool.
# These candidates are:
#
#
# 🧠 Business Insight
# Extremely well-defined salary structure
# Very low variance → indicates healthy, predictable job market
# Ideal pipeline for mass scaling
# Bulk recruitment & standard salary grids work well here
#
#
# **Cluster 2 — Mid‑Senior, Experienced Tech Talent**
# 📌 Size: 28,434 profiles
# 📌 Avg CTC: ₹18.6 L
# 📌 Avg Experience: 10.5 years
# 📌 CTC Range: 2 L – 50 L
# 📌 Dominant Role: Backend Engineer
# 📌 Dominant Company Hash: ioklnz
# 🔍 Interpretation
# This is the core mid-to-senior engineering workforce.
#
# Strong experience (≈10 yrs)
# Salary nearly 2× Cluster 1
# Clear upward progression
# Mixed mid- and senior-level roles
# Broader company distribution
#
# 🧠 Business Insight
# This cluster defines your senior tech compensation benchmark.
# Consistent salary progression relative to experience
# Healthy market segmentation
# The 50 L upper band indicates tech lead / principal roles

# %% [markdown]
# ## Conclusion 9: - Hierarchical clustering

# %%
sample_df_mrg_ctc_shrink = df_mrg_ctc_shrink

# %%
df_mrg_ctc_shrink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139095 entries, 0 to 139094
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   company_hash        139095 non-null  object
#  1   job_position_clean  139095 non-null  object
#  2   experience          139095 non-null  float64
#  3   ctc                 139095 non-null  int64
#  4   cluster             139095 non-null  int32
# dtypes: float64(1), int32(1), int64(1), object(2)
# memory usage: 4.8+ MB

# %%
X_pca
# Out:
# array([[-0.83596174, -0.32444775],
#        [-0.62767811,  0.32982334],
#        [ 0.0200926 ,  0.34611426],
#        ...,
#        [-0.87767391, -0.36799398],
#        [-0.84344177, -0.333771  ],
#        [ 1.95361207,  3.20632856]])

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# 'ward' linkage works well with Euclidean distance and continuous data
Z = linkage(X_pca, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(Z, truncate_mode='level', p=5)  # truncate to show top merges
plt.title("Hierarchical Clustering Dendrogram (truncated)")
plt.xlabel("Sample index or (cluster size)")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# #Conclusion 9 : Based on Dandogram K = 3 (Orange, Green and Blue)

# %% [markdown]
# Insight Meaning
# K = 3
# Best top-level clusteringVery large height jumpsClusters are strongly separatedSubclusters inside clustersCan do finer segmentation if neededCluster size imbalanceSome job profiles are more commonCluster compactness differsSome groups are very clean, some more spread

# %% [markdown]
# #Following is AI Generated output for student's reference:
# Here is a clear, **data‑driven interpretation** of your attached dendrogram, with **practical insights** you can use for clustering and your business analysis.
#
# I will explain what the structure shows, how many clusters are appropriate, and what this means for your segmentation (company + role + experience).
#
# ***
#
# # 📊 **Hierarchical Clustering Dendrogram – Interpretation**
#
# Your dendrogram shows three colored regions:
#
# *   **Orange cluster (left)**
# *   **Green cluster (right)**
# *   Both ultimately merge at the very top (\~70 distance)
#
# Let’s decode what this means.
#
# ***
#
# # ✅ **1. The dataset has TWO strong, well‑separated clusters**
#
# The single biggest vertical jump happens at the **top blue merge** at height \~70.
#
# This means:
#
# 👉 **Two major clusters** naturally exist in your data
#
# *   Left side = Orange
# *   Right side = Green
#
# These two groups are **very different in feature space**
# (company\_hash, job\_position\_clean, experience).
#
# This is reinforced by:
#
# *   Large vertical distance
# *   No early merging between orange and green
# *   Clear separation at mid‑distance levels
#
# ***
#
# # ✅ **2. Within each major cluster, there are meaningful subclusters**
#
# ### **Orange Section (Left)**
#
# *   Internal merges happen mostly at height **5–25**
# *   Indicates a **homogeneous** group with:
#     *   similar role patterns
#     *   similar experience bands
#     *   companies with similar compensation profile
#
# This often corresponds to:
# 👉 **Early to mid‑career common roles** (e.g., backend engineers in typical companies)
#
# ***
#
# ### **Green Section (Right)**
#
# *   Internal merges occur at height **10–40**
# *   This cluster is more **spread-out and diverse**
# *   Contains:
#     *   broader role variations
#     *   broader experience range
#     *   higher salary variance segments
#
# This often corresponds to:
# 👉 **Senior / advanced / niche talent**
# with more variability in salary behavior.
#
# ***
#
# # ✅ **3. Natural number of clusters = 2 or 3**
#
# Based on merge heights:
#
# ### ✔ If you want **broad segmentation**:
#
# **Cut at height \~45** → **2 clusters**
#
# *   Orange group
# *   Green group
#
# ### ✔ If you want **meaningful but finer segmentation**:
#
# **Cut at height \~25** → **3 clusters**
#
# *   Orange cluster splits into 2 subclusters
# *   Green cluster remains as 1 big subcluster
#
# ### ✔ If you want **very fine segmentation** for salary bands:
#
# Cut at height \~10 → 5–7 clusters
#
# But **2 or 3** are the most defensible based on dendrogram structure.
#
# ***
#
# # ✅ **4. Orange vs Green: What differences does the dendrogram reveal?**
#
# ### **Orange group (left)**
#
# *   Tighter, lower-distance merges
# *   More consistency
# *   More predictable salary and experience distribution
# *   High volume profiles
# *   Likely your **junior → mid-level** population
#
# ### **Green group (right)**
#
# *   Larger distances
# *   Wider spread
# *   More variability in role/company patterns
# *   Contains smaller but more distinct pockets
# *   Likely your **mid → senior** or **premium** population
#
# ***
#
# # 📌 **5. Business Insight from Cluster Structure**
#
# Even without salary in the dendrogram, this structure already reveals:
#
# ### **Insight 1 – Two distinct talent markets exist**
#
# One aligned across standard roles/companies (orange),
# and one broader and more complex (green).
#
# ### **Insight 2 – The green cluster indicates salary diversity**
#
# Because merges happen at higher distances, salary is likely more varied.
#
# ### **Insight 3 – Orange cluster is ideal for strict salary banding**
#
# Due to compactness and low distance between subclusters.
#
# ### **Insight 4 – Green cluster requires more flexible compensation rules**
#
# Due to greater heterogeneity—probably seniority or niche role effects.
#
# ### **Insight 5 – You can align salary normalization strategy accordingly:**
#
# *   Cluster A (Orange): **fixed, standardized compensation grid**
# *   Cluster B (Green): **experience/company‑tier sensitive compensation**
#
# This aligns with your earlier GROUPBY insights where
# Cluster 1 (junior), Cluster 2 (senior), Cluster 0 (high‑salary niche) emerged.
#
# ***
#
# # 🎯 **6. Recommended Next Step**
#
# If your goal is salary segmentation:
#
# *   **Use K = 3**
#     It matches the dendrogram’s fine-level structure
#     and your salary cluster summary (entry, mid, niche).
#
# If you want broader segmentation:
#
# *   **Use K = 2**
#     Simple split between standard and advanced talent.
#
# ***
